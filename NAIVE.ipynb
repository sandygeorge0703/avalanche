# %% [markdown]
# ## Importing libraries

# %%
from torch.utils.data import DataLoader, Sampler, SubsetRandomSampler
from torch.utils.data import Dataset
from PIL import Image
from PIL import ImageFile
from tqdm import tqdm  
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import random
import os
import torch
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import pandas as pd
from avalanche.evaluation.metrics import forgetting_metrics, accuracy_metrics,\
    loss_metrics, timing_metrics, cpu_usage_metrics, StreamConfusionMatrix,\
    disk_usage_metrics
from avalanche.logging import InteractiveLogger, TextLogger, TensorboardLogger
from avalanche.training.plugins import EvaluationPlugin
from avalanche.training import Naive
from torch.optim import SGD
from torch.nn import CrossEntropyLoss
from avalanche.benchmarks import nc_benchmark
from models.cnn_models import SimpleCNN



# Allow loading of truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Set the random seed for reproducibility
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)  # If using a GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)
random.seed(seed)

# %% [markdown]
# ## Define filepaths as constant

# %%
# Define file paths as constants
CSV_FILE_PATH = r'C:\Users\Sandhra George\avalanche\data\dataset.csv'
ROOT_DIR_PATH = r'C:\Users\Sandhra George\avalanche\caxton_dataset\print24'

csv_file = r'C:\Users\Sandhra George\avalanche\data\dataset.csv'  # Path to the CSV file
root_dir = r'C:\Users\Sandhra George\avalanche\caxton_dataset\print24'  # Path to the image directory

# %% [markdown]
# ## Load data into DataFrame and filter print24

# %%
# Load data into a DataFrame for easier processing
data = pd.read_csv(CSV_FILE_PATH)

# Limit dataset to the images between row indices 454 and 7058 (inclusive)
#data_limited = data.iloc[454:7059].reset_index(drop=True)

# Filter the dataset to only include images containing "print24"
data_filtered = data[data.iloc[:, 0].str.contains('print24', na=False)]

# Update the first column to contain only the image filenames
data_filtered.iloc[:, 0] = data_filtered.iloc[:, 0].str.replace(r'.*?/(image-\d+\.jpg)', r'\1', regex=True)

# Display the updated DataFrame
print("First rows of filtered DataFrame:")
print(data_filtered.head())

# Display the last few rows of the updated DataFrame
print("\nLast rows of filtered DataFrame:")
print(data_filtered.tail())
# Out:
# First rows of filtered DataFrame:
#           img_path               timestamp  flow_rate  feed_rate  z_offset  \
# 99496  image-4.jpg  2020-10-07T11:45:35-86        100        100       0.0
# 99497  image-5.jpg  2020-10-07T11:45:36-32        100        100       0.0
# 99498  image-6.jpg  2020-10-07T11:45:36-79        100        100       0.0
# 99499  image-7.jpg  2020-10-07T11:45:37-26        100        100       0.0
# 99500  image-8.jpg  2020-10-07T11:45:37-72        100        100       0.0
#
#        target_hotend  hotend    bed  nozzle_tip_x  nozzle_tip_y  img_num  \
# 99496          205.0  204.86  64.83           654           560        3
# 99497          205.0  204.62  65.08           654           560        4
# 99498          205.0  204.62  65.08           654           560        5
# 99499          205.0  204.62  65.08           654           560        6
# 99500          205.0  204.62  65.08           654           560        7
#
#        print_id  flow_rate_class  feed_rate_class  z_offset_class  \
# 99496        24                1                1               1
# 99497        24                1                1               1
# 99498        24                1                1               1
# 99499        24                1                1               1
# 99500        24                1                1               1
#
#        hotend_class   img_mean    img_std
# 99496             1  21.047311  31.160557
# 99497             1  23.239277  32.133393
# 99498             1  23.686270  31.702140
# 99499             1  21.645111  31.329910
# 99500             1  20.883776  32.322521
#
# Last rows of filtered DataFrame:
#                img_path               timestamp  flow_rate  feed_rate  \
# 120639  image-26633.jpg  2020-10-07T15:11:15-03        167         39
# 120640  image-26634.jpg  2020-10-07T15:11:15-48        167         39
# 120641  image-26635.jpg  2020-10-07T15:11:15-94        167         39
# 120642  image-26636.jpg  2020-10-07T15:11:16-40        167         39
# 120643  image-26637.jpg  2020-10-07T15:11:16-85        167         39
#
#         z_offset  target_hotend  hotend    bed  nozzle_tip_x  nozzle_tip_y  \
# 120639     -0.02          226.0  226.00  65.05           654           560
# 120640     -0.02          226.0  226.00  65.05           654           560
# 120641     -0.02          226.0  226.00  65.05           654           560
# 120642     -0.02          226.0  226.00  65.05           654           560
# 120643     -0.02          226.0  226.25  64.94           654           560
#
#         img_num  print_id  flow_rate_class  feed_rate_class  z_offset_class  \
# 120639    26632        24                2                0               1
# 120640    26633        24                2                0               1
# 120641    26634        24                2                0               1
# 120642    26635        24                2                0               1
# 120643    26636        24                2                0               1
#
#         hotend_class    img_mean    img_std
# 120639             2   99.738226  71.471386
# 120640             2  102.395052  72.259859
# 120641             2  105.231595  74.336885
# 120642             2   97.592887  67.624012
# 120643             2   97.459404  67.672459

# %% [markdown]
# ## Analysing the target hotend temperature column

# %%
# Extract unique temperatures in the 'target_hotend' column and sort them
unique_temperatures = sorted(data_filtered['target_hotend'].unique())  # Sort temperatures in ascending order

# Calculate the full range of temperatures (min and max)
temperature_min = data_filtered['target_hotend'].min()
temperature_max = data_filtered['target_hotend'].max()

# Print the unique temperatures (sorted), count, and full range
print("\nUnique target hotend temperatures in the dataset (sorted):")
print(unique_temperatures)
print(f"\nNumber of unique target hotend temperatures: {len(unique_temperatures)}")
print(f"Temperature range: {temperature_min} to {temperature_max}")
# Out:
# Unique target hotend temperatures in the dataset (sorted):
# [180.0, 181.0, 182.0, 183.0, 184.0, 185.0, 186.0, 187.0, 188.0, 189.0, 190.0, 191.0, 192.0, 193.0, 194.0, 195.0, 196.0, 197.0, 198.0, 199.0, 200.0, 201.0, 202.0, 203.0, 204.0, 205.0, 206.0, 207.0, 208.0, 209.0, 210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0, 219.0, 220.0, 221.0, 222.0, 223.0, 224.0, 225.0, 226.0, 227.0, 228.0, 229.0, 230.0]
#
# Number of unique target hotend temperatures: 51
# Temperature range: 180.0 to 230.0

# %% [markdown]
# ## Create a random temperature sub list and new dataframes with equal class distribution

# %%
# Extract unique temperatures and sort them
unique_temperatures = sorted(data_filtered['target_hotend'].unique())  # Sort temperatures in ascending order

# Check if we have enough unique temperatures to select from
if len(unique_temperatures) >= 50:
    # Select the lowest and highest temperatures
    temperature_min = unique_temperatures[0]
    temperature_max = unique_temperatures[-1]

    # Remove the lowest and highest temperatures from the unique temperatures list
    remaining_temperatures = [temp for temp in unique_temperatures if temp != temperature_min and temp != temperature_max]

    # Randomly select 40 other temperatures from the remaining ones
    random_temperatures = random.sample(remaining_temperatures, 40)

    # Add the random temperatures to the temperature_sublist
    temperature_sublist = [temperature_min, temperature_max] + random_temperatures
    
    # Sort from lowest to highest hotend temperature
    temperature_sublist = sorted(temperature_sublist)

    # Print the temperature sublist
    print("\nTemperature sublist:")
    print(temperature_sublist)
    
    # Split into three experience groups
    split_size = len(temperature_sublist) // 3
    experience_1 = temperature_sublist[:split_size]  # First third
    experience_2 = temperature_sublist[split_size:2*split_size]  # Second third
    experience_3 = temperature_sublist[2*split_size:]  # Last third

    # Print the results
    print("\nExperience Group 1:", experience_1)
    print("\nExperience Group 2:", experience_2)
    print("\nExperience Group 3:", experience_3)
else:
    print("Not enough unique temperatures to select from. At least 50 unique temperatures are required.")
    experience_1 = experience_2 = experience_3 = []

# Initialize a dictionary to store DataFrames for each class per experience
experience_datasets = {1: {}, 2: {}, 3: {}}

# Iterate through the three experience groups
for exp_id, experience_temps in enumerate([experience_1, experience_2, experience_3], start=1):
    if not experience_temps:
        print(f"Skipping Experience {exp_id} due to insufficient temperatures.")
        continue

    print(f"\nProcessing Experience {exp_id} with temperatures: {experience_temps}...")

    # Filter the dataset based on the current experience's temperature range
    exp_data = data_filtered[data_filtered['target_hotend'].isin(experience_temps)]
    
    # Check if exp_data is empty after filtering
    if exp_data.empty:
        print(f"No data found for Experience {exp_id} with temperatures {experience_temps}. Skipping...")
        continue

    # Create a dictionary to store class-wise data for this experience
    class_datasets = {}

    # Iterate through each class (0, 1, 2) and filter data
    for class_id in [0, 1, 2]:
        class_data = exp_data[exp_data['hotend_class'] == class_id]
        
        if class_data.empty:
            print(f"Warning: Class {class_id} in Experience {exp_id} has no data!")
        else:
            class_datasets[class_id] = class_data
            print(f"Class {class_id} dataset size in Experience {exp_id}: {len(class_data)}")

    # Ensure that all classes have data before proceeding to balance
    if len(class_datasets) != 3:
        print(f"Skipping Experience {exp_id} because one or more classes are missing data!")
        continue  # Skip processing this experience if any class has no data

    # Find the smallest class size in this experience
    min_class_size = min(len(class_datasets[class_id]) for class_id in class_datasets)
    print(f"Smallest class size in Experience {exp_id}: {min_class_size}")

    # Balance the dataset for this experience
    balanced_data = []

    for class_id in class_datasets:
        class_data = class_datasets[class_id]
        # Randomly sample 'min_class_size' images from the class data to balance class distribution
        sampled_class_data = class_data.sample(n=min_class_size, random_state=42)  # Sample equally
        balanced_data.append(sampled_class_data)

    # Combine all class data for this experience into one balanced dataset
    balanced_dataset = pd.concat(balanced_data).reset_index(drop=True)

    # Shuffle the final balanced dataset
    balanced_dataset = balanced_dataset.sample(frac=1, random_state=42).reset_index(drop=True)

    # Store the balanced dataset in the experience_datasets dictionary
    experience_datasets[exp_id] = balanced_dataset

    # Print summary for this experience
    print(f"\nBalanced dataset size for Experience {exp_id}: {len(balanced_dataset)}")
    print("Number of images in each class after balancing:")

    for class_id in [0, 1, 2]:
        class_count = len(balanced_dataset[balanced_dataset['hotend_class'] == class_id])
        print(f"Class {class_id}: {class_count} images")

    print("-" * 50)

# Print the first few rows for verification
for exp_id in [1, 2, 3]:
    if exp_id in experience_datasets:
        print(f"\nFirst five rows of Experience {exp_id} dataset:")
        print(experience_datasets[exp_id].head())
# Out:
# Temperature sublist:
# [180.0, 181.0, 182.0, 183.0, 184.0, 185.0, 186.0, 189.0, 190.0, 191.0, 192.0, 193.0, 195.0, 196.0, 198.0, 199.0, 201.0, 203.0, 204.0, 205.0, 206.0, 207.0, 208.0, 209.0, 210.0, 212.0, 213.0, 215.0, 216.0, 217.0, 218.0, 219.0, 220.0, 221.0, 222.0, 223.0, 224.0, 225.0, 227.0, 228.0, 229.0, 230.0]
#
# Experience Group 1: [180.0, 181.0, 182.0, 183.0, 184.0, 185.0, 186.0, 189.0, 190.0, 191.0, 192.0, 193.0, 195.0, 196.0]
#
# Experience Group 2: [198.0, 199.0, 201.0, 203.0, 204.0, 205.0, 206.0, 207.0, 208.0, 209.0, 210.0, 212.0, 213.0, 215.0]
#
# Experience Group 3: [216.0, 217.0, 218.0, 219.0, 220.0, 221.0, 222.0, 223.0, 224.0, 225.0, 227.0, 228.0, 229.0, 230.0]
#
# Processing Experience 1 with temperatures: [180.0, 181.0, 182.0, 183.0, 184.0, 185.0, 186.0, 189.0, 190.0, 191.0, 192.0, 193.0, 195.0, 196.0]...
# Class 0 dataset size in Experience 1: 5511
# Class 1 dataset size in Experience 1: 830
# Class 2 dataset size in Experience 1: 33
# Smallest class size in Experience 1: 33
#
# Balanced dataset size for Experience 1: 99
# Number of images in each class after balancing:
# Class 0: 33 images
# Class 1: 33 images
# Class 2: 33 images
# --------------------------------------------------
#
# Processing Experience 2 with temperatures: [198.0, 199.0, 201.0, 203.0, 204.0, 205.0, 206.0, 207.0, 208.0, 209.0, 210.0, 212.0, 213.0, 215.0]...
# Class 0 dataset size in Experience 2: 553
# Class 1 dataset size in Experience 2: 5139
# Class 2 dataset size in Experience 2: 39
# Smallest class size in Experience 2: 39
#
# Balanced dataset size for Experience 2: 117
# Number of images in each class after balancing:
# Class 0: 39 images
# Class 1: 39 images
# Class 2: 39 images
# --------------------------------------------------
#
# Processing Experience 3 with temperatures: [216.0, 217.0, 218.0, 219.0, 220.0, 221.0, 222.0, 223.0, 224.0, 225.0, 227.0, 228.0, 229.0, 230.0]...
# Class 0 dataset size in Experience 3: 258
# Class 1 dataset size in Experience 3: 3110
# Class 2 dataset size in Experience 3: 2176
# Smallest class size in Experience 3: 258
#
# Balanced dataset size for Experience 3: 774
# Number of images in each class after balancing:
# Class 0: 258 images
# Class 1: 258 images
# Class 2: 258 images
# --------------------------------------------------
#
# First five rows of Experience 1 dataset:
#          img_path               timestamp  flow_rate  feed_rate  z_offset  \
# 0  image-4218.jpg  2020-10-07T12:18:14-82        158         63      0.00
# 1  image-2684.jpg  2020-10-07T12:06:22-05         70         51      0.00
# 2  image-7142.jpg  2020-10-07T12:40:53-91         71        142      0.18
# 3    image-86.jpg  2020-10-07T11:46:14-03         59         25      0.16
# 4  image-7149.jpg  2020-10-07T12:40:57-17         71        142      0.18
#
#    target_hotend  hotend    bed  nozzle_tip_x  nozzle_tip_y  img_num  \
# 0          195.0  195.11  64.61           654           560     4217
# 1          196.0  195.54  65.29           654           560     2683
# 2          185.0  224.33  65.38           654           560     7141
# 3          185.0  185.49  65.37           654           560       85
# 4          185.0  221.07  65.69           654           560     7148
#
#    print_id  flow_rate_class  feed_rate_class  z_offset_class  hotend_class  \
# 0        24                2                0               1             1
# 1        24                0                0               1             1
# 2        24                0                2               2             2
# 3        24                0                0               2             0
# 4        24                0                2               2             2
#
#     img_mean    img_std
# 0  69.857819  33.965096
# 1  60.200889  46.691070
# 2  65.622393  41.818446
# 3  34.551976  39.183701
# 4  65.601012  42.230603
#
# First five rows of Experience 2 dataset:
#           img_path               timestamp  flow_rate  feed_rate  z_offset  \
# 0  image-23871.jpg  2020-10-07T14:50:01-08        196         89      0.30
# 1   image-6563.jpg  2020-10-07T12:36:24-89        176         47      0.01
# 2  image-23955.jpg  2020-10-07T14:50:39-87         63         42      0.08
# 3   image-6031.jpg  2020-10-07T12:32:17-56         23        148      0.22
# 4   image-8956.jpg  2020-10-07T12:54:56-92         93        152      0.18
#
#    target_hotend  hotend    bed  nozzle_tip_x  nozzle_tip_y  img_num  \
# 0          208.0  208.55  65.28           654           560    23870
# 1          199.0  192.61  65.13           654           560     6562
# 2          199.0  196.59  65.02           654           560    23954
# 3          205.0  199.74  64.98           654           560     6030
# 4          198.0  190.28  65.30           654           560     8955
#
#    print_id  flow_rate_class  feed_rate_class  z_offset_class  hotend_class  \
# 0        24                2                1               2             1
# 1        24                2                0               1             0
# 2        24                0                0               2             1
# 3        24                0                2               2             1
# 4        24                1                2               2             0
#
#      img_mean    img_std
# 0  116.067884  88.183680
# 1   73.471120  36.935715
# 2   73.028395  77.640018
# 3   69.554671  53.564753
# 4   83.951292  42.550099
#
# First five rows of Experience 3 dataset:
#           img_path               timestamp  flow_rate  feed_rate  z_offset  \
# 0  image-22920.jpg  2020-10-07T14:42:42-68        108         26      0.25
# 1   image-3059.jpg  2020-10-07T12:09:16-29         73        199      0.19
# 2   image-1630.jpg  2020-10-07T11:58:11-64         28        113      0.31
# 3  image-21531.jpg  2020-10-07T14:32:01-23        144        190      0.26
# 4  image-14485.jpg  2020-10-07T13:37:46-76         55         80      0.11
#
#    target_hotend  hotend    bed  nozzle_tip_x  nozzle_tip_y  img_num  \
# 0          221.0  204.41  65.36           654           560    22919
# 1          221.0  215.31  65.24           654           560     3058
# 2          224.0  220.94  64.70           654           560     1629
# 3          228.0  194.35  65.01           654           560    21530
# 4          225.0  213.67  65.10           654           560    14484
#
#    print_id  flow_rate_class  feed_rate_class  z_offset_class  hotend_class  \
# 0        24                1                0               2             1
# 1        24                0                2               2             1
# 2        24                0                1               2             2
# 3        24                2                2               2             0
# 4        24                0                0               2             1
#
#      img_mean    img_std
# 0  104.894141  72.685579
# 1   51.158066  34.351055
# 2   57.269925  46.027715
# 3  107.999629  64.725795
# 4   88.975638  66.855594

# %% [markdown]
# ## Checking the class distribution of all the experience datasets

# %%
# Iterate over all experience datasets (1, 2, 3)
for exp_id in [1, 2, 3]:
    # Check if the experience dataset exists (in case an experience was skipped)
    if exp_id in experience_datasets:
        # Select only the 'img_path' and 'hotend_class' columns
        balanced_dataset_filtered = experience_datasets[exp_id][['img_path', 'hotend_class']]

        # Check the class distribution in the filtered dataset
        class_distribution = balanced_dataset_filtered['hotend_class'].value_counts()
        
        # Print the class distribution for the current experience
        print(f"\nClass distribution for Experience {exp_id}:")
        print(class_distribution)
# Out:
# Class distribution for Experience 1:
# hotend_class
# 1    33
# 2    33
# 0    33
# Name: count, dtype: int64
#
# Class distribution for Experience 2:
# hotend_class
# 1    39
# 0    39
# 2    39
# Name: count, dtype: int64
#
# Class distribution for Experience 3:
# hotend_class
# 1    258
# 2    258
# 0    258
# Name: count, dtype: int64

# %% [markdown]
# ## Printing the indices, the classes, and the number of images in each class

# %%
# Iterate over all experience datasets (1, 2, 3)
for exp_id in [1, 2, 3]:
    # Check if the experience dataset exists (in case an experience was skipped)
    if exp_id in experience_datasets:
        # Select only the 'img_path' and 'hotend_class' columns for the current experience dataset
        balanced_dataset_filtered = experience_datasets[exp_id][['img_path', 'hotend_class']]

        # Get the class distribution for the current experience dataset
        class_distribution = balanced_dataset_filtered['hotend_class'].value_counts()
        
        # Step 1: Print the indices, the classes, and the number of images in each class
        print(f"\n--- Experience {exp_id} ---")
        for class_label in class_distribution.index:
            # Get all indices for the current class
            class_indices = balanced_dataset_filtered[balanced_dataset_filtered['hotend_class'] == class_label].index.tolist()

            # Count the number of images for the current class
            num_images_in_class = len(class_indices)

            # Print the details for this class
            print(f"\nClass: {class_label} (Total images: {num_images_in_class})")
            print("Indices: ", class_indices)
            print(f"Number of images in class {class_label}: {num_images_in_class}")

        # Step 2: Get the number of unique classes
        num_classes = len(class_distribution)

        # Step 3: Set a small batch size
        small_batch_size = 15  # You can change this to a value like 32, 64, etc.

        # Step 4: Calculate the number of samples per class per batch
        samples_per_class = small_batch_size // num_classes  # Ensure it's divisible

        # Make sure we don't ask for more samples than available in the smallest class
        samples_per_class = min(samples_per_class, class_distribution.min())

        # Step 5: Calculate the total batch size
        batch_size = samples_per_class * num_classes

        print(f"\nRecommended Small Batch Size for Experience {exp_id}: {batch_size}")
        print(f"Samples per class in Experience {exp_id}: {samples_per_class}")
        print("-" * 50)  # To separate each experience's results
# Out:
# --- Experience 1 ---
#
# Class: 1 (Total images: 33)
# Indices:  [0, 1, 6, 7, 12, 14, 20, 24, 25, 29, 35, 37, 40, 42, 47, 52, 57, 59, 61, 62, 63, 65, 67, 70, 71, 72, 74, 78, 79, 81, 84, 94, 98]
# Number of images in class 1: 33
#
# Class: 2 (Total images: 33)
# Indices:  [2, 4, 5, 11, 18, 19, 21, 22, 27, 30, 33, 36, 39, 45, 54, 56, 58, 60, 64, 66, 68, 69, 73, 75, 77, 80, 88, 89, 90, 91, 92, 95, 97]
# Number of images in class 2: 33
#
# Class: 0 (Total images: 33)
# Indices:  [3, 8, 9, 10, 13, 15, 16, 17, 23, 26, 28, 31, 32, 34, 38, 41, 43, 44, 46, 48, 49, 50, 51, 53, 55, 76, 82, 83, 85, 86, 87, 93, 96]
# Number of images in class 0: 33
#
# Recommended Small Batch Size for Experience 1: 15
# Samples per class in Experience 1: 5
# --------------------------------------------------
#
# --- Experience 2 ---
#
# Class: 1 (Total images: 39)
# Indices:  [0, 2, 3, 6, 10, 16, 18, 20, 25, 28, 31, 34, 35, 39, 41, 45, 46, 49, 51, 53, 54, 55, 63, 74, 75, 77, 79, 83, 84, 85, 87, 88, 91, 92, 98, 105, 110, 111, 115]
# Number of images in class 1: 39
#
# Class: 0 (Total images: 39)
# Indices:  [1, 4, 8, 9, 11, 14, 15, 23, 24, 26, 27, 29, 33, 36, 37, 40, 43, 47, 48, 50, 52, 56, 57, 60, 61, 64, 66, 67, 68, 70, 89, 94, 95, 97, 99, 100, 101, 109, 113]
# Number of images in class 0: 39
#
# Class: 2 (Total images: 39)
# Indices:  [5, 7, 12, 13, 17, 19, 21, 22, 30, 32, 38, 42, 44, 58, 59, 62, 65, 69, 71, 72, 73, 76, 78, 80, 81, 82, 86, 90, 93, 96, 102, 103, 104, 106, 107, 108, 112, 114, 116]
# Number of images in class 2: 39
#
# Recommended Small Batch Size for Experience 2: 15
# Samples per class in Experience 2: 5
# --------------------------------------------------
#
# --- Experience 3 ---
#
# Class: 1 (Total images: 258)
# Indices:  [0, 1, 4, 14, 15, 18, 21, 23, 30, 32, 33, 34, 35, 39, 43, 44, 45, 48, 49, 51, 53, 54, 64, 65, 66, 68, 70, 71, 73, 74, 82, 87, 89, 92, 93, 95, 99, 105, 106, 107, 110, 112, 115, 126, 127, 129, 135, 136, 139, 144, 147, 150, 152, 157, 159, 161, 162, 163, 171, 172, 174, 175, 176, 179, 183, 184, 195, 196, 198, 199, 201, 203, 206, 209, 212, 217, 219, 222, 229, 230, 232, 236, 237, 242, 243, 244, 245, 247, 248, 252, 253, 258, 263, 264, 266, 270, 275, 276, 279, 281, 283, 284, 286, 287, 289, 297, 304, 306, 308, 309, 310, 312, 314, 315, 323, 328, 330, 331, 337, 338, 340, 342, 349, 353, 355, 356, 362, 363, 364, 371, 372, 374, 375, 376, 378, 379, 381, 390, 393, 395, 406, 408, 409, 410, 413, 415, 417, 421, 422, 425, 426, 427, 428, 435, 437, 439, 444, 445, 446, 450, 455, 458, 469, 490, 492, 493, 495, 497, 502, 503, 505, 511, 512, 519, 533, 534, 538, 546, 548, 552, 553, 554, 559, 565, 566, 567, 574, 575, 576, 580, 582, 585, 594, 596, 597, 599, 600, 604, 607, 608, 610, 611, 612, 613, 614, 618, 619, 620, 643, 647, 648, 658, 659, 667, 668, 669, 670, 671, 673, 676, 685, 686, 690, 691, 693, 694, 696, 700, 701, 704, 711, 712, 713, 714, 716, 718, 721, 723, 724, 728, 730, 737, 739, 741, 745, 746, 748, 750, 751, 752, 753, 754, 759, 761, 762, 764, 771, 772]
# Number of images in class 1: 258
#
# Class: 2 (Total images: 258)
# Indices:  [2, 5, 6, 7, 9, 10, 16, 27, 31, 36, 37, 38, 40, 41, 42, 50, 52, 55, 56, 57, 59, 63, 76, 77, 78, 80, 84, 85, 86, 98, 102, 103, 108, 109, 113, 116, 117, 120, 121, 122, 125, 128, 130, 134, 138, 141, 142, 143, 145, 146, 151, 158, 160, 165, 166, 167, 168, 169, 170, 185, 192, 194, 200, 207, 210, 213, 214, 215, 223, 225, 226, 228, 231, 238, 239, 241, 250, 254, 257, 260, 262, 265, 267, 269, 273, 285, 293, 294, 295, 298, 300, 301, 303, 311, 313, 320, 321, 322, 324, 326, 329, 333, 334, 345, 348, 352, 354, 357, 360, 361, 365, 367, 368, 369, 370, 373, 380, 383, 384, 387, 388, 391, 392, 396, 397, 398, 401, 402, 404, 405, 407, 411, 416, 420, 423, 430, 436, 438, 440, 443, 448, 451, 453, 460, 461, 462, 465, 466, 470, 471, 472, 473, 474, 475, 477, 479, 480, 481, 485, 486, 488, 489, 491, 494, 498, 501, 510, 513, 514, 515, 517, 518, 520, 521, 522, 524, 526, 527, 528, 531, 539, 541, 542, 544, 549, 550, 551, 556, 557, 558, 562, 563, 564, 570, 572, 583, 586, 587, 588, 590, 591, 592, 593, 595, 598, 603, 606, 609, 616, 617, 621, 622, 623, 624, 625, 626, 627, 628, 632, 634, 636, 637, 638, 640, 642, 644, 645, 649, 652, 653, 654, 655, 657, 665, 672, 677, 679, 680, 695, 699, 703, 706, 707, 717, 722, 726, 727, 729, 732, 733, 734, 736, 738, 742, 755, 757, 766, 768]
# Number of images in class 2: 258
#
# Class: 0 (Total images: 258)
# Indices:  [3, 8, 11, 12, 13, 17, 19, 20, 22, 24, 25, 26, 28, 29, 46, 47, 58, 60, 61, 62, 67, 69, 72, 75, 79, 81, 83, 88, 90, 91, 94, 96, 97, 100, 101, 104, 111, 114, 118, 119, 123, 124, 131, 132, 133, 137, 140, 148, 149, 153, 154, 155, 156, 164, 173, 177, 178, 180, 181, 182, 186, 187, 188, 189, 190, 191, 193, 197, 202, 204, 205, 208, 211, 216, 218, 220, 221, 224, 227, 233, 234, 235, 240, 246, 249, 251, 255, 256, 259, 261, 268, 271, 272, 274, 277, 278, 280, 282, 288, 290, 291, 292, 296, 299, 302, 305, 307, 316, 317, 318, 319, 325, 327, 332, 335, 336, 339, 341, 343, 344, 346, 347, 350, 351, 358, 359, 366, 377, 382, 385, 386, 389, 394, 399, 400, 403, 412, 414, 418, 419, 424, 429, 431, 432, 433, 434, 441, 442, 447, 449, 452, 454, 456, 457, 459, 463, 464, 467, 468, 476, 478, 482, 483, 484, 487, 496, 499, 500, 504, 506, 507, 508, 509, 516, 523, 525, 529, 530, 532, 535, 536, 537, 540, 543, 545, 547, 555, 560, 561, 568, 569, 571, 573, 577, 578, 579, 581, 584, 589, 601, 602, 605, 615, 629, 630, 631, 633, 635, 639, 641, 646, 650, 651, 656, 660, 661, 662, 663, 664, 666, 674, 675, 678, 681, 682, 683, 684, 687, 688, 689, 692, 697, 698, 702, 705, 708, 709, 710, 715, 719, 720, 725, 731, 735, 740, 743, 744, 747, 749, 756, 758, 760, 763, 765, 767, 769, 770, 773]
# Number of images in class 0: 258
#
# Recommended Small Batch Size for Experience 3: 15
# Samples per class in Experience 3: 5
# --------------------------------------------------

# %% [markdown]
# ## At this point a balanced dataset for each experience has been created

# %% [markdown]
# ## Create training, validation, and testing datasets

# %%
# Iterate over all experience datasets (1, 2, 3)
for exp_id in [1, 2, 3]:
    # Check if the experience dataset exists (in case an experience was skipped)
    if exp_id in experience_datasets:
        # Select only the 'img_path' and 'hotend_class' columns for the current experience dataset
        balanced_dataset_filtered = experience_datasets[exp_id][['img_path', 'hotend_class']]

        # Number of images per class (this will be the same after balancing)
        num_images_per_class = len(balanced_dataset_filtered) // 3  # Assuming there are 3 classes (0, 1, 2)

        # Calculate the number of samples per class for train, validation, and test sets
        train_size = int(0.8 * num_images_per_class)
        valid_size = int(0.1 * num_images_per_class)
        test_size = num_images_per_class - train_size - valid_size

        # Lists to hold indices for each class's dataset (train, validation, test)
        train_indices, valid_indices, test_indices = [], [], []

        # Split the data by class (assuming classes are 0, 1, 2)
        for class_label in [0, 1, 2]:
            class_data = balanced_dataset_filtered[balanced_dataset_filtered['hotend_class'] == class_label].index.tolist()

            # Shuffle the indices of the current class
            random.shuffle(class_data)

            # Split the indices for each class into train, validation, and test
            train_indices.extend(class_data[:train_size])
            valid_indices.extend(class_data[train_size:train_size + valid_size])
            test_indices.extend(class_data[train_size + valid_size:])

        # Sort the indices to ensure consistent processing
        train_indices, valid_indices, test_indices = sorted(train_indices), sorted(valid_indices), sorted(test_indices)

        # Create DataFrames for train, validation, and test sets based on the indices
        globals()[f'train_{exp_id}'] = balanced_dataset_filtered.loc[train_indices].reset_index(drop=True)
        globals()[f'valid_{exp_id}'] = balanced_dataset_filtered.loc[valid_indices].reset_index(drop=True)
        globals()[f'test_{exp_id}'] = balanced_dataset_filtered.loc[test_indices].reset_index(drop=True)

        # Count class distribution for each of the datasets
        def count_class_distribution(indices):
            class_counts = [0, 0, 0]  # Assuming 3 classes (0, 1, 2)
            for index in indices:
                class_label = balanced_dataset_filtered.loc[index, 'hotend_class']
                class_counts[class_label] += 1
            return class_counts

        # Count class distribution for each of the datasets
        train_class_distribution = count_class_distribution(train_indices)
        valid_class_distribution = count_class_distribution(valid_indices)
        test_class_distribution = count_class_distribution(test_indices)

        # Print the class distribution and dataset sizes
        print(f"\n--- Experience {exp_id} ---")
        print(f"Train set size: {len(train_indices)} | Class distribution: {train_class_distribution}")
        print(f"Validation set size: {len(valid_indices)} | Class distribution: {valid_class_distribution}")
        print(f"Test set size: {len(test_indices)} | Class distribution: {test_class_distribution}")

        print(f"Experience {exp_id} datasets created successfully!\n")

# Now, the datasets are directly available as:
# train_1, valid_1, test_1, train_2, valid_2, test_2, train_3, valid_3, test_3
# Out:
# --- Experience 1 ---
# Train set size: 78 | Class distribution: [26, 26, 26]
# Validation set size: 9 | Class distribution: [3, 3, 3]
# Test set size: 12 | Class distribution: [4, 4, 4]
# Experience 1 datasets created successfully!
#
#
# --- Experience 2 ---
# Train set size: 93 | Class distribution: [31, 31, 31]
# Validation set size: 9 | Class distribution: [3, 3, 3]
# Test set size: 15 | Class distribution: [5, 5, 5]
# Experience 2 datasets created successfully!
#
#
# --- Experience 3 ---
# Train set size: 618 | Class distribution: [206, 206, 206]
# Validation set size: 75 | Class distribution: [25, 25, 25]
# Test set size: 81 | Class distribution: [27, 27, 27]
# Experience 3 datasets created successfully!

# %% [markdown]
# ## Check for Missing or Invalid Labels in Training, Validation, and Test Data

# %%
# Check for any missing labels or invalid labels
print(train_1['hotend_class'].isnull().sum())  # Count missing labels
print(train_1['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values

print(train_2['hotend_class'].isnull().sum())  # Count missing labels
print(train_2['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values

print(train_3['hotend_class'].isnull().sum())  # Count missing labels
print(train_3['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values

print(valid_1['hotend_class'].isnull().sum())  # Count missing labels
print(valid_1['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values

print(valid_2['hotend_class'].isnull().sum())  # Count missing labels
print(valid_2['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values

print(valid_3['hotend_class'].isnull().sum())  # Count missing labels
print(valid_3['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values

print(test_1['hotend_class'].isnull().sum())  # Count missing labels
print(test_1['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values

print(test_2['hotend_class'].isnull().sum())  # Count missing labels
print(test_2['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values

print(test_3['hotend_class'].isnull().sum())  # Count missing labels
print(test_3['hotend_class'].unique())  # Check unique labels to ensure there are no unexpected values
# Out:
# 0
# [1 2 0]
# 0
# [1 0 2]
# 0
# [1 0 2]
# 0
# [1 2 0]
# 0
# [2 0 1]
# 0
# [2 1 0]
# 0
# [1 2 0]
# 0
# [2 0 1]
# 0
# [2 1 0]

# %% [markdown]
# ## Balanced Dataset class

# %%
# Define the dataset class
class BalancedDataset(Dataset):
    def __init__(self, data_frame, root_dir, transform=None):
        self.data = data_frame
        self.root_dir = root_dir
        self.transform = transform or transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
        
        # Validate that the images exist in the directory
        self.valid_indices = self.get_valid_indices()

    def get_valid_indices(self):
        valid_indices = []
        for idx in tqdm(range(len(self.data)), desc="Validating images"):
            img_name = self.data.iloc[idx, 0].strip()
            img_name = img_name.split('/')[-1]  # Extract file name
            
            if img_name.startswith("image-"):
                try:
                    # Ensure we only include images in the valid range
                    image_number = int(img_name.split('-')[1].split('.')[0])
                    if 4 <= image_number <= 26637:
                        full_img_path = os.path.join(self.root_dir, img_name)
                        if os.path.exists(full_img_path):
                            valid_indices.append(idx)
                        else:
                            print(f"Image does not exist: {full_img_path}")
                except ValueError:
                    print(f"Invalid filename format for {img_name}. Skipping...")
        
        print(f"Total valid indices found: {len(valid_indices)}")  # Debugging output
        return valid_indices

    def __len__(self):
            return len(self.valid_indices)
    
    def __getitem__(self, idx):
        # Wrap around the index if it exceeds the length of valid indices
        idx = idx % len(self.valid_indices)
        
        # Get the actual index from valid indices
        actual_idx = self.valid_indices[idx]
        img_name = self.data.iloc[actual_idx, 0].strip()
        full_img_path = os.path.join(self.root_dir, img_name)
        label = self.targets[actual_idx]  # Get the label from the targets tensor
    
        try:
            # Attempt to open the image and convert to RGB
            image = Image.open(full_img_path).convert('RGB')
    
            # Apply transformations if defined
            if self._transform_groups.get('train'):
                image = self._transform_groups['train'](image)
    
            return image, label, task_label  # Return image, label, and task label
        except (OSError, IOError, ValueError) as e:
            # Print error message for debugging
            print(f"Error loading image {full_img_path}: {e}")
    
            # Handle gracefully by skipping the corrupted/missing file
            return self.__getitem__((idx + 1) % len(self.valid_indices))  # Try next valid index

# %% [markdown]
# ## Balanced Batch Sampler class

# %%
class BalancedBatchSampler(Sampler):
    def __init__(self, data_frame, batch_size=15, samples_per_class=5):
        """
        data_frame: Pandas DataFrame with image paths and their respective class labels.
        batch_size: Total batch size.
        samples_per_class: Number of samples to draw from each class per batch.
        """
        self.data_frame = data_frame
        self.batch_size = batch_size
        self.samples_per_class = samples_per_class
        self.num_classes = len(data_frame['hotend_class'].unique())
        
        if self.batch_size % self.num_classes != 0:
            raise ValueError("Batch size must be divisible by the number of classes.")

        self.class_indices = {
            class_id: self.data_frame[self.data_frame['hotend_class'] == class_id].index.tolist()
            for class_id in self.data_frame['hotend_class'].unique()
        }
        
        # Shuffle class indices initially
        for class_id in self.class_indices:
            random.shuffle(self.class_indices[class_id])

        self.num_samples_per_epoch = sum(len(indices) for indices in self.class_indices.values())
        self.indices_used = {class_id: [] for class_id in self.class_indices}

    def __iter__(self):
        batches = []

        # Replenish indices for each class
        for class_id in self.class_indices:
            if not self.class_indices[class_id]:
                raise ValueError(f"Class {class_id} has no samples. Cannot form balanced batches.")

            # Shuffle and use all indices from this class
            self.indices_used[class_id] = self.class_indices[class_id].copy()
            random.shuffle(self.indices_used[class_id])

        # Generate balanced batches
        while len(batches) * self.batch_size < self.num_samples_per_epoch:
            batch = []
            for class_id in self.indices_used:
                if len(self.indices_used[class_id]) < self.samples_per_class:
                    # If a class runs out of samples, reshuffle and replenish
                    self.indices_used[class_id] = self.class_indices[class_id].copy()
                    random.shuffle(self.indices_used[class_id])

                # Take `samples_per_class` indices from the current class
                batch.extend(self.indices_used[class_id][:self.samples_per_class])
                self.indices_used[class_id] = self.indices_used[class_id][self.samples_per_class:]

            # Shuffle the batch and append
            random.shuffle(batch)
            batches.append(batch)

        return iter(batches)

    def __len__(self):
        # Total number of batches per epoch
        return self.num_samples_per_epoch // self.batch_size

# %%
# Define a dictionary to store datasets and DataLoaders
datasets = {}
dataloaders = {}

# Iterate over all experience datasets (1, 2, 3)
for exp_id in [1, 2, 3]:
    # Ensure the dataset exists
    if f"train_{exp_id}" in globals():
        train_data = globals()[f"train_{exp_id}"]
        val_data = globals()[f"valid_{exp_id}"]
        test_data = globals()[f"test_{exp_id}"]

        # Create dataset instances
        datasets[f"train_{exp_id}"] = BalancedDataset(data_frame=train_data, root_dir=root_dir)
        datasets[f"valid_{exp_id}"] = BalancedDataset(data_frame=val_data, root_dir=root_dir)
        datasets[f"test_{exp_id}"] = BalancedDataset(data_frame=test_data, root_dir=root_dir)

        # Create batch samplers for balanced training
        train_sampler = BalancedBatchSampler(data_frame=train_data, batch_size=15, samples_per_class=5)
        val_sampler = BalancedBatchSampler(data_frame=val_data, batch_size=15, samples_per_class=5)
        test_sampler = BalancedBatchSampler(data_frame=test_data, batch_size=15, samples_per_class=5)

        # Create DataLoaders
        dataloaders[f"train_{exp_id}"] = DataLoader(datasets[f"train_{exp_id}"], batch_sampler=train_sampler, shuffle=False)
        dataloaders[f"valid_{exp_id}"] = DataLoader(datasets[f"valid_{exp_id}"], batch_sampler=val_sampler, shuffle=False)
        dataloaders[f"test_{exp_id}"] = DataLoader(datasets[f"test_{exp_id}"], batch_sampler=test_sampler)

        # Print dataset lengths
        print(f"   Experience {exp_id} datasets and DataLoaders created successfully!")
        print(f"   Train dataset length: {len(datasets[f'train_{exp_id}'])}")
        print(f"   Validation dataset length: {len(datasets[f'valid_{exp_id}'])}")
        print(f"   Test dataset length: {len(datasets[f'test_{exp_id}'])}")
# Out:
# Validating images: 100%|██████████| 78/78 [00:00<00:00, 1226.02it/s]
# Total valid indices found: 78
# Validating images: 100%|██████████| 9/9 [00:00<00:00, 1283.93it/s]
# Total valid indices found: 9
# Validating images: 100%|██████████| 12/12 [00:00<00:00, 1200.40it/s]
# Total valid indices found: 12
#    Experience 1 datasets and DataLoaders created successfully!
#    Train dataset length: 78
#    Validation dataset length: 9
#    Test dataset length: 12
# Validating images: 100%|██████████| 93/93 [00:00<00:00, 1770.80it/s]
# Total valid indices found: 93
# Validating images: 100%|██████████| 9/9 [00:00<00:00, 1124.98it/s]
# Total valid indices found: 9
# Validating images: 100%|██████████| 15/15 [00:00<00:00, 1875.75it/s]
# Total valid indices found: 15
#    Experience 2 datasets and DataLoaders created successfully!
#    Train dataset length: 93
#    Validation dataset length: 9
#    Test dataset length: 15
# Validating images: 100%|██████████| 618/618 [00:00<00:00, 2403.72it/s]
# Total valid indices found: 618
# Validating images: 100%|██████████| 75/75 [00:00<00:00, 2807.56it/s]
# Total valid indices found: 75
# Validating images: 100%|██████████| 81/81 [00:00<00:00, 2892.77it/s]
# Total valid indices found: 81
#    Experience 3 datasets and DataLoaders created successfully!
#    Train dataset length: 618
#    Validation dataset length: 75
#    Test dataset length: 81

# %% [markdown]
# ## Setting up a new folder for each experiment

# %%
# Set base directory
base_dir = "experiments"
os.makedirs(base_dir, exist_ok=True)

# Function to get the next experiment folder
def get_experiment_folder(exp_num):
    return os.path.join(base_dir, f"Experiment_{exp_num:02d}")  # Keeps two-digit format (01, 02, ..., 10)

# Set initial experiment number
experiment_num = 1
experiment_folder = get_experiment_folder(experiment_num)

# Create the main experiment directory if it doesn't exist
os.makedirs(experiment_folder, exist_ok=True)

# Set model path inside experiment folder
model_path = os.path.join(experiment_folder, "best_model.pth")

# Create subdirectories for training, validation, and test confusion matrices
train_folder = os.path.join(experiment_folder, "training_confusion_matrices")
val_folder = os.path.join(experiment_folder, "validation_confusion_matrices")
test_folder = os.path.join(experiment_folder, "test_confusion_matrices")

# Ensure that the subdirectories exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Print the directory where results will be saved
print(f"Saving results to: {experiment_folder}")
# Out:
# Saving results to: experiments\Experiment_01

# %% [markdown]
# ## Display a Random Image from the Dataset with Its Label

# %%
import random
import os
import matplotlib.pyplot as plt

def save_random_image_from_experiment(exp_id, dataset_type):
    """
    Selects a random image from the specified dataset (train, valid, or test) for a given experience ID,
    loads it, displays it, and saves it to the corresponding experiment folder.

    Args:
        exp_id (int): The experience group number (1, 2, or 3).
        dataset_type (str): The dataset type - 'train', 'valid', or 'test'.
    """
    # Ensure the dataset exists
    dataset_key = f"{dataset_type}_{exp_id}"  # Example: 'train_1', 'valid_2', 'test_3'
    if dataset_key not in datasets:
        print(f"Dataset {dataset_key} not found!")
        return

    dataset = datasets[dataset_key]  # Retrieve the dataset
    data_frame = dataset.data  # Get the underlying DataFrame

    # Ensure the dataset is not empty
    if data_frame.empty:
        print(f"Dataset {dataset_key} is empty!")
        return

    # Select a random index
    random_index = random.choice(data_frame.index)
    img_path = os.path.join(root_dir, data_frame.iloc[random_index, 0].strip())
    label = data_frame.loc[random_index, 'hotend_class']

    # Load and display the image
    img = plt.imread(img_path)
    plt.imshow(img)
    plt.title(f"Label: {label}")

    # Define the path to save the image inside the current experiment folder
    experiment_folder = os.path.join("experiments", f"experiment_{exp_id}")
    os.makedirs(experiment_folder, exist_ok=True)  # Ensure folder exists

    output_path = os.path.join(experiment_folder, f"random_{dataset_type}.png")

    # Save the figure
    plt.savefig(output_path)
    plt.clf()  # Clear the plot to avoid overlaps

    print(f"Image saved to: {output_path}")

# Example Usage:
save_random_image_from_experiment(exp_id=1, dataset_type='train')  # Random training image from Experience 1
save_random_image_from_experiment(exp_id=2, dataset_type='valid')  # Random validation image from Experience 2
save_random_image_from_experiment(exp_id=3, dataset_type='test')   # Random test image from Experience 3
# Out:
# Image saved to: experiments\experiment_1\random_train.png
# Image saved to: experiments\experiment_2\random_valid.png
# Image saved to: experiments\experiment_3\random_test.png

# %%
# Iterate over all experience groups
for exp_id in [1, 2, 3]:  
    dataset_key = f"train_{exp_id}"  # e.g., 'train_1', 'train_2', 'train_3'
    
    # Ensure the dataset exists
    if dataset_key in datasets:
        data_frame = datasets[dataset_key].data  # Access the DataFrame from BalancedDataset

        # Ensure the dataset is not empty
        if not data_frame.empty:
            # First image
            first_index = data_frame.index[0]
            first_image = data_frame.loc[first_index, 'img_path']
            first_label = data_frame.loc[first_index, 'hotend_class']
            print(f"Experience {exp_id} - First Image Path: {first_image}, First Label: {first_label}")

            # Last image
            last_index = data_frame.index[-1]
            last_image = data_frame.loc[last_index, 'img_path']
            last_label = data_frame.loc[last_index, 'hotend_class']
            print(f"Experience {exp_id} - Last Image Path: {last_image}, Last Label: {last_label}\n")
        else:
            print(f"Experience {exp_id} - Training dataset is empty!\n")
    else:
        print(f"Experience {exp_id} - Training dataset not found!\n")
# Out:
# Experience 1 - First Image Path: image-4218.jpg, First Label: 1
# Experience 1 - Last Image Path: image-21301.jpg, Last Label: 1
#
# Experience 2 - First Image Path: image-23871.jpg, First Label: 1
# Experience 2 - Last Image Path: image-1427.jpg, Last Label: 2
#
# Experience 3 - First Image Path: image-22920.jpg, First Label: 1
# Experience 3 - Last Image Path: image-394.jpg, Last Label: 0

# %% [markdown]
# ## Creating  Naive Class which inherits from AvalancheDataset and contains all the expected functions

# %%
import os
from tqdm import tqdm
from PIL import Image
import torch
from torch.utils.data import Dataset
from torchvision import transforms
from avalanche.benchmarks.utils import AvalancheDataset, DataAttribute
from avalanche.benchmarks.utils.transforms import TupleTransform

class NaiveCompatibleBalancedDataset(AvalancheDataset):
    def __init__(self, data_frame, root_dir=None, transform=None, task_label=0, indices=None):
        """
        Custom dataset compatible with Naive that inherits from AvalancheDataset.
        It loads images from disk, applies transforms, and provides sample-wise
        attributes for targets and task labels.
        
        Args:
            data_frame (pd.DataFrame or list): If a DataFrame, it must contain columns
                'image_path' and 'hotend_class'. If a list, it is assumed to be a pre-built
                list of datasets (used in subset calls).
            root_dir (str, optional): Directory where images are stored. Must be provided if data_frame is a DataFrame.
            transform (callable, optional): Transformations to apply.
            task_label (int, optional): Task label for continual learning.
            indices (Sequence[int], optional): Optional indices for subsetting.
        """
        # If data_frame is a list, assume this is a call from subset() and forward the call.
        if isinstance(data_frame, list):
            super().__init__(data_frame, indices=indices)
            return

        # Otherwise, data_frame is a DataFrame. Ensure root_dir is provided.
        if root_dir is None:
            raise ValueError("root_dir must be provided when data_frame is a DataFrame")
        
        # Reset DataFrame index for consistency.
        self.data = data_frame.reset_index(drop=True)
        self.root_dir = root_dir
        self.task_label = task_label

        # Define a default transform if none provided.
        default_transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
        ])
        # Wrap the transform in TupleTransform so that it applies only to the image element.
        self._transform_groups = {
            "train": TupleTransform([transform or default_transform]),
            "eval": TupleTransform([transform or default_transform])
        }
        
        # Ensure required columns exist.
        if 'hotend_class' not in self.data.columns:
            raise ValueError("DataFrame must contain 'hotend_class' for labels.")
        if 'image_path' not in self.data.columns:
            raise ValueError("DataFrame must contain 'image_path' for image paths.")
        
        # Validate image paths and obtain valid indices.
        valid_indices = self.get_valid_indices()
        if len(valid_indices) == 0:
            raise ValueError("No valid image paths found.")
        
        # Compute targets and task labels for valid samples.
        targets_data = torch.tensor(self.data.loc[valid_indices, 'hotend_class'].values)
        targets_task_labels_data = torch.full_like(targets_data, self.task_label)
        
        # Prepare sample entries (one per valid image).
        samples = []
        for idx in valid_indices:
            img_name = self.data.loc[idx, 'image_path'].strip()
            full_img_path = os.path.join(self.root_dir, img_name)
            label = int(self.data.loc[idx, 'hotend_class'])
            samples.append({
                "img_path": full_img_path,
                "label": label,
                "task_label": self.task_label
            })
        
        # Define an internal basic dataset that loads images.
        class BasicDataset(Dataset):
            def __init__(self, samples):
                self.samples = samples

            def __len__(self):
                return len(self.samples)

            def __getitem__(self, idx):
                sample = self.samples[idx]
                img_path = sample["img_path"]
                try:
                    # Load the image (ensure it is a PIL image).
                    image = Image.open(img_path).convert('RGB')
                except Exception as e:
                    print(f"Error loading image {img_path}: {e}")
                    # If an error occurs, try the next sample.
                    return self.__getitem__((idx + 1) % len(self.samples))
                return image, sample["label"], sample["task_label"]
        
        basic_dataset = BasicDataset(samples)
        
        # Create data attributes.
        data_attributes = [
            DataAttribute(targets_data, name="targets", use_in_getitem=True),
            DataAttribute(targets_task_labels_data, name="targets_task_labels", use_in_getitem=True)
        ]
        
        # IMPORTANT: Pass the basic_dataset inside a list so that AvalancheDataset
        # correctly sets up its internal flat data, and forward the indices parameter.
        super().__init__(
            [basic_dataset],
            data_attributes=data_attributes,
            transform_groups=self._transform_groups,
            indices=indices
        )
    
    def get_valid_indices(self):
        """Return indices for which the image file exists."""
        valid_indices = []
        for idx in tqdm(range(len(self.data)), desc="Validating images"):
            img_name = self.data.loc[idx, 'image_path'].strip()
            full_img_path = os.path.join(self.root_dir, img_name)
            if os.path.exists(full_img_path):
                valid_indices.append(idx)
            else:
                print(f"Image does not exist: {full_img_path}")
        print(f"Total valid images: {len(valid_indices)}")
        return valid_indices

# %% [markdown]
# ## Creating training, validation and testing datasets to implement Naive

# %%
from torchvision import transforms

# Define the transformation (e.g., normalization)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Experience 1
train_dataset_exp1 = NaiveCompatibleBalancedDataset(
    data_frame=train_1.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)

val_dataset_exp1 = NaiveCompatibleBalancedDataset(
    data_frame=valid_1.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)

test_dataset_exp1 = NaiveCompatibleBalancedDataset(
    data_frame=test_1.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)

# Experience 2
train_dataset_exp2 = NaiveCompatibleBalancedDataset(
    data_frame=train_2.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)

val_dataset_exp2 = NaiveCompatibleBalancedDataset(
    data_frame=valid_2.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)

test_dataset_exp2 = NaiveCompatibleBalancedDataset(
    data_frame=test_2.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)

# Experience 3
train_dataset_exp3 = NaiveCompatibleBalancedDataset(
    data_frame=train_3.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)

val_dataset_exp3 = NaiveCompatibleBalancedDataset(
    data_frame=valid_3.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)

test_dataset_exp3 = NaiveCompatibleBalancedDataset(
    data_frame=test_3.rename(columns={'img_path': 'image_path', 'class': 'hotend_class'}),
    root_dir=root_dir,
    transform=transform,
    task_label=0
)
# Out:
# Validating images: 100%|██████████| 78/78 [00:00<00:00, 11146.70it/s]
# Total valid images: 78
# Validating images: 100%|██████████| 9/9 [00:00<00:00, 5972.90it/s]
# Total valid images: 9
# Validating images: 100%|██████████| 12/12 [00:00<00:00, 6009.03it/s]
# Total valid images: 12
# Validating images: 100%|██████████| 93/93 [00:00<00:00, 11153.47it/s]
# Total valid images: 93
# Validating images: 100%|██████████| 9/9 [00:00<00:00, 4108.04it/s]
# Total valid images: 9
# Validating images: 100%|██████████| 15/15 [00:00<00:00, 3735.58it/s]
# Total valid images: 15
# Validating images: 100%|██████████| 618/618 [00:00<00:00, 8884.04it/s]
# Total valid images: 618
# Validating images: 100%|██████████| 75/75 [00:00<00:00, 8329.08it/s]
# Total valid images: 75
# Validating images: 100%|██████████| 81/81 [00:00<00:00, 11564.39it/s]
# Total valid images: 81

# %% [markdown]
# ## Creating Dataloaders for more efficient data processing

# %%
from torch.utils.data.dataloader import DataLoader

# Experience 1
train_sampler_exp1 = BalancedBatchSampler(data_frame=train_1.rename(columns={'img_path': 'image_path'}), 
                                          batch_size=15, samples_per_class=5)
val_sampler_exp1 = BalancedBatchSampler(data_frame=valid_1.rename(columns={'img_path': 'image_path'}), 
                                        batch_size=15, samples_per_class=5)
test_sampler_exp1 = BalancedBatchSampler(data_frame=test_1.rename(columns={'img_path': 'image_path'}), 
                                         batch_size=15, samples_per_class=5)

train_loader_exp1 = DataLoader(train_dataset_exp1, batch_sampler=train_sampler_exp1, shuffle=False)
val_loader_exp1 = DataLoader(val_dataset_exp1, batch_sampler=val_sampler_exp1, shuffle=False)
test_loader_exp1 = DataLoader(test_dataset_exp1, batch_sampler=test_sampler_exp1, shuffle=False)

# Experience 2
train_sampler_exp2 = BalancedBatchSampler(data_frame=train_2.rename(columns={'img_path': 'image_path'}), 
                                          batch_size=15, samples_per_class=5)
val_sampler_exp2 = BalancedBatchSampler(data_frame=valid_2.rename(columns={'img_path': 'image_path'}), 
                                        batch_size=15, samples_per_class=5)
test_sampler_exp2 = BalancedBatchSampler(data_frame=test_2.rename(columns={'img_path': 'image_path'}), 
                                         batch_size=15, samples_per_class=5)

train_loader_exp2 = DataLoader(train_dataset_exp2, batch_sampler=train_sampler_exp2, shuffle=False)
val_loader_exp2 = DataLoader(val_dataset_exp2, batch_sampler=val_sampler_exp2, shuffle=False)
test_loader_exp2 = DataLoader(test_dataset_exp2, batch_sampler=test_sampler_exp2, shuffle=False)

# Experience 3
train_sampler_exp3 = BalancedBatchSampler(data_frame=train_3.rename(columns={'img_path': 'image_path'}), 
                                          batch_size=15, samples_per_class=5)
val_sampler_exp3 = BalancedBatchSampler(data_frame=valid_3.rename(columns={'img_path': 'image_path'}), 
                                        batch_size=15, samples_per_class=5)
test_sampler_exp3 = BalancedBatchSampler(data_frame=test_3.rename(columns={'img_path': 'image_path'}), 
                                         batch_size=15, samples_per_class=5)

train_loader_exp3 = DataLoader(train_dataset_exp3, batch_sampler=train_sampler_exp3, shuffle=False)
val_loader_exp3 = DataLoader(val_dataset_exp3, batch_sampler=val_sampler_exp3, shuffle=False)
test_loader_exp3 = DataLoader(test_dataset_exp3, batch_sampler=test_sampler_exp3, shuffle=False)

# Print to check if the DataLoaders are created successfully
print("DataLoaders for all experiences created successfully!")
# Out:
# DataLoaders for all experiences created successfully!

# %% [markdown]
# ## Checking if the datasets are AvalancheDatasets and whether they contain the correct Attributes

# %%
# Function to check if a dataset is an instance of AvalancheDataset
def check_avalanche_dataset(dataset):
    # Check if dataset is an instance of AvalancheDataset
    if isinstance(dataset, AvalancheDataset):
        print(f"Dataset is an instance of AvalancheDataset.")
    else:
        print(f"Dataset is NOT an instance of AvalancheDataset.")
        
    # Inspect the internal structure to understand where the data attributes are stored
    print(f"Dataset internal structure: {dir(dataset)}")

    # Check if dataset has the core attributes: 'data', 'targets', 'task_label'
    if hasattr(dataset, 'data') and hasattr(dataset, 'targets') and hasattr(dataset, 'task_label'):
        print("Dataset contains 'data', 'targets', and 'task_label' attributes.")
    else:
        print("Dataset is missing one or more of the required attributes: 'data', 'targets', 'task_label'.")
        
    # Verify the length and sample data
    try:
        # Let's print the first sample to see how data is structured
        sample = dataset[0]
        print(f"First sample structure: {sample}")
    except Exception as e:
        print(f"Error fetching first sample: {e}")
    
    # If there's data, check for its expected shape and content
    if hasattr(dataset, 'data'):
        print(f"Dataset contains data with shape: {len(dataset.data)} samples.")
    
    if hasattr(dataset, 'targets'):
        print(f"Dataset contains targets with length: {len(dataset.targets)}.")

# Experience 1
check_avalanche_dataset(train_dataset_exp1)
check_avalanche_dataset(val_dataset_exp1)
check_avalanche_dataset(test_dataset_exp1)

# Experience 2
check_avalanche_dataset(train_dataset_exp2)
check_avalanche_dataset(val_dataset_exp2)
check_avalanche_dataset(test_dataset_exp2)

# Experience 3
check_avalanche_dataset(train_dataset_exp3)
check_avalanche_dataset(val_dataset_exp3)
check_avalanche_dataset(test_dataset_exp3)
# Out:
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-1.6042, -1.6213, -1.6384,  ..., -0.5424, -0.5938, -0.5767],
#          [-1.6042, -1.6213, -1.6384,  ..., -0.5424, -0.5767, -0.5424],
#          [-1.6042, -1.6384, -1.6727,  ..., -0.4568, -0.4911, -0.4911],
#          ...,
#          [-1.8439, -1.8610, -1.8782,  ...,  0.0227,  0.1083,  0.1426],
#          [-1.8610, -1.8782, -1.8953,  ..., -0.0801,  0.0398,  0.1426],
#          [-1.8610, -1.8953, -1.8953,  ..., -0.1314, -0.0287,  0.0741]],
#
#         [[-1.5105, -1.5105, -1.5105,  ..., -0.3901, -0.4601, -0.4426],
#          [-1.5105, -1.5105, -1.5105,  ..., -0.3725, -0.4601, -0.4426],
#          [-1.4930, -1.5105, -1.5455,  ..., -0.3550, -0.4251, -0.4426],
#          ...,
#          [-1.7206, -1.7206, -1.7206,  ...,  0.2227,  0.2402,  0.2402],
#          [-1.7031, -1.7206, -1.7381,  ...,  0.1877,  0.1877,  0.1877],
#          [-1.6856, -1.7206, -1.7206,  ...,  0.1352,  0.1352,  0.1352]],
#
#         [[-1.2641, -1.3861, -1.4733,  ..., -0.7587, -0.8284, -0.8284],
#          [-1.2641, -1.3861, -1.4733,  ..., -0.7761, -0.7413, -0.5844],
#          [-1.3164, -1.4210, -1.5256,  ..., -0.7064, -0.6193, -0.4798],
#          ...,
#          [-1.3339, -1.3861, -1.4907,  ..., -0.0964, -0.0092,  0.0431],
#          [-1.4559, -1.4733, -1.5081,  ..., -0.2881, -0.1661, -0.0441],
#          [-1.5604, -1.5953, -1.5953,  ..., -0.4450, -0.3230, -0.2010]]]), 1, 0, 1, 0]
# Dataset contains data with shape: 78 samples.
# Dataset contains targets with length: 78.
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-1.6727, -1.6042, -1.7069,  ..., -0.7137, -0.8164, -0.9020],
#          [-1.6384, -1.6384, -1.6898,  ..., -0.7137, -0.8164, -0.9020],
#          [-1.5870, -1.6555, -1.6727,  ..., -0.7308, -0.7993, -0.8678],
#          ...,
#          [-0.5596, -0.6109, -0.6281,  ..., -0.3712, -0.3883, -0.3883],
#          [-0.5596, -0.6281, -0.6623,  ..., -0.3541, -0.3541, -0.3712],
#          [-0.5596, -0.5938, -0.6109,  ..., -0.3712, -0.3712, -0.3712]],
#
#         [[-1.5630, -1.4930, -1.5805,  ..., -0.4601, -0.5651, -0.6702],
#          [-1.5280, -1.5280, -1.5805,  ..., -0.4601, -0.5651, -0.6702],
#          [-1.4755, -1.5455, -1.5630,  ..., -0.4601, -0.5651, -0.6527],
#          ...,
#          [-0.2325, -0.2675, -0.2850,  ..., -0.0574, -0.0574, -0.0399],
#          [-0.2150, -0.2675, -0.3025,  ..., -0.0224, -0.0049, -0.0224],
#          [-0.1975, -0.2150, -0.2325,  ..., -0.0399, -0.0224, -0.0224]],
#
#         [[-1.4210, -1.3513, -1.4907,  ..., -1.0898, -1.1421, -1.1421],
#          [-1.3861, -1.3861, -1.4733,  ..., -1.0898, -1.1421, -1.1421],
#          [-1.3687, -1.4210, -1.4733,  ..., -1.1421, -1.0550, -1.0550],
#          ...,
#          [-0.8633, -1.0027, -1.0550,  ..., -1.0724, -1.1421, -1.2467],
#          [-0.9156, -1.0724, -1.1247,  ..., -1.0724, -1.1770, -1.2816],
#          [-1.0201, -1.1421, -1.1596,  ..., -1.1247, -1.1944, -1.2816]]]), 1, 0, 1, 0]
# Dataset contains data with shape: 9 samples.
# Dataset contains targets with length: 9.
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-0.9020, -1.0048, -1.0219,  ..., -0.9020, -0.9877, -1.0048],
#          [-0.9020, -1.0048, -1.0219,  ..., -0.9020, -0.9877, -1.0048],
#          [-0.9020, -1.0048, -1.0390,  ..., -0.9534, -1.0048, -1.0390],
#          ...,
#          [-0.5253, -0.4397, -0.3369,  ..., -0.1657, -0.1657, -0.1828],
#          [-0.5253, -0.4397, -0.3712,  ..., -0.1486, -0.1314, -0.1486],
#          [-0.5253, -0.4397, -0.3883,  ..., -0.1486, -0.1143, -0.1143]],
#
#         [[-0.8627, -0.9678, -1.0028,  ..., -0.6702, -0.7752, -0.8277],
#          [-0.8627, -0.9678, -1.0028,  ..., -0.6702, -0.8102, -0.8452],
#          [-0.8627, -0.9678, -1.0028,  ..., -0.7227, -0.8102, -0.8452],
#          ...,
#          [-0.2150, -0.1975, -0.1625,  ...,  0.2052,  0.1877,  0.1877],
#          [-0.2150, -0.2150, -0.1800,  ...,  0.2227,  0.1877,  0.1702],
#          [-0.2150, -0.2150, -0.1975,  ...,  0.2052,  0.2227,  0.2052]],
#
#         [[-1.4210, -1.5256, -1.5256,  ..., -1.5430, -1.5779, -1.5081],
#          [-1.4210, -1.5256, -1.5430,  ..., -1.4733, -1.4733, -1.4210],
#          [-1.4210, -1.5256, -1.5779,  ..., -1.3861, -1.3687, -1.3687],
#          ...,
#          [-1.6127, -1.6650, -1.7347,  ..., -1.7347, -1.6824, -1.7522],
#          [-1.6127, -1.6650, -1.7522,  ..., -1.7696, -1.6999, -1.6650],
#          [-1.6127, -1.6650, -1.7347,  ..., -1.7347, -1.7696, -1.5953]]]), 1, 0, 1, 0]
# Dataset contains data with shape: 12 samples.
# Dataset contains targets with length: 12.
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-0.1828, -0.2171, -0.2856,  ..., -1.1418, -1.1589, -1.1760],
#          [-0.1486, -0.1828, -0.2513,  ..., -1.1589, -1.1932, -1.2103],
#          [-0.1486, -0.1828, -0.2342,  ..., -1.1760, -1.2103, -1.2274],
#          ...,
#          [ 2.1975,  2.1975,  2.1975,  ..., -0.5596, -0.5596, -0.5424],
#          [ 2.1975,  2.1975,  2.1975,  ..., -0.5767, -0.5424, -0.5253],
#          [ 2.1975,  2.1975,  2.1975,  ..., -0.5938, -0.5424, -0.5253]],
#
#         [[-0.6001, -0.6527, -0.7227,  ..., -1.1078, -1.1253, -1.1429],
#          [-0.5651, -0.6176, -0.7052,  ..., -1.1429, -1.1779, -1.1954],
#          [-0.5651, -0.6176, -0.6527,  ..., -1.1779, -1.2129, -1.2304],
#          ...,
#          [ 2.3761,  2.3761,  2.3761,  ..., -0.4076, -0.3901, -0.3901],
#          [ 2.3761,  2.3761,  2.3761,  ..., -0.3901, -0.3725, -0.3550],
#          [ 2.3761,  2.3761,  2.3761,  ..., -0.3725, -0.3725, -0.3550]],
#
#         [[-1.8044, -1.8044, -1.8044,  ..., -1.6824, -1.6824, -1.6999],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.6476, -1.6302, -1.6476],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.6127, -1.5953, -1.6127],
#          ...,
#          [ 2.5877,  2.5877,  2.5877,  ..., -0.0267,  0.0082,  0.0082],
#          [ 2.5877,  2.5877,  2.5703,  ..., -0.0441, -0.0267, -0.0092],
#          [ 2.5877,  2.5877,  2.5703,  ..., -0.0267, -0.0267, -0.0092]]]), 1, 0, 1, 0]
# Dataset contains data with shape: 93 samples.
# Dataset contains targets with length: 93.
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-1.7412, -1.7925, -1.8268,  ..., -0.5424, -0.6794, -0.7308],
#          [-1.7240, -1.7412, -1.8268,  ..., -0.5596, -0.6452, -0.7308],
#          [-1.7583, -1.7583, -1.8268,  ..., -0.6109, -0.6452, -0.7308],
#          ...,
#          [-0.6109, -0.5938, -0.5938,  ..., -0.3369, -0.3027, -0.3027],
#          [-0.6281, -0.6109, -0.6109,  ..., -0.3027, -0.2856, -0.2684],
#          [-0.5938, -0.5938, -0.5938,  ..., -0.3027, -0.3027, -0.2684]],
#
#         [[-1.6331, -1.6856, -1.7206,  ..., -0.3550, -0.4426, -0.5476],
#          [-1.6155, -1.6331, -1.7031,  ..., -0.3901, -0.4426, -0.5651],
#          [-1.6331, -1.6155, -1.6856,  ..., -0.4426, -0.4601, -0.6001],
#          ...,
#          [-0.3025, -0.3025, -0.2850,  ...,  0.0301,  0.0826,  0.0651],
#          [-0.3200, -0.3200, -0.3025,  ...,  0.0826,  0.1176,  0.1176],
#          [-0.2675, -0.2850, -0.2850,  ...,  0.1176,  0.1352,  0.1527]],
#
#         [[-1.4733, -1.6302, -1.6999,  ..., -1.1421, -1.3339, -1.1944],
#          [-1.4559, -1.5779, -1.7173,  ..., -1.0898, -1.1944, -1.1247],
#          [-1.5953, -1.6302, -1.7347,  ..., -1.1073, -1.0201, -1.0376],
#          ...,
#          [-1.2119, -1.2119, -1.2293,  ..., -1.3339, -1.2990, -1.1596],
#          [-1.2293, -1.2293, -1.2293,  ..., -1.3513, -1.3164, -1.2990],
#          [-1.2990, -1.3164, -1.2990,  ..., -1.5256, -1.5256, -1.4907]]]), 2, 0, 2, 0]
# Dataset contains data with shape: 9 samples.
# Dataset contains targets with length: 9.
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-1.7583, -1.7583, -1.8097,  ..., -0.4397, -0.4739, -0.4911],
#          [-1.7583, -1.7583, -1.8097,  ..., -0.4397, -0.4739, -0.4911],
#          [-1.7583, -1.7583, -1.8097,  ..., -0.4226, -0.4397, -0.4568],
#          ...,
#          [-0.3027, -0.3027, -0.3027,  ...,  2.2489,  2.2489,  2.2489],
#          [-0.3027, -0.3027, -0.3027,  ...,  2.2489,  2.2489,  2.2489],
#          [-0.3027, -0.3027, -0.3027,  ...,  2.2489,  2.2489,  2.2489]],
#
#         [[-1.7031, -1.7031, -1.7556,  ..., -0.8277, -0.8803, -0.9153],
#          [-1.7031, -1.7031, -1.7556,  ..., -0.8277, -0.8803, -0.9153],
#          [-1.7031, -1.7031, -1.7556,  ..., -0.8627, -0.8978, -0.9153],
#          ...,
#          [-0.1975, -0.1975, -0.1975,  ...,  1.2381,  1.2206,  1.2206],
#          [-0.1975, -0.1975, -0.1975,  ...,  1.2381,  1.2381,  1.2381],
#          [-0.1975, -0.1975, -0.1975,  ...,  1.2556,  1.2556,  1.2381]],
#
#         [[-1.6824, -1.6824, -1.7347,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.6824, -1.6824, -1.7347,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.7173, -1.7173, -1.7522,  ..., -1.8044, -1.8044, -1.8044],
#          ...,
#          [ 0.1476,  0.1476,  0.1476,  ..., -1.8044, -1.8044, -1.8044],
#          [ 0.1128,  0.1128,  0.1302,  ..., -1.8044, -1.8044, -1.8044],
#          [ 0.1128,  0.1128,  0.1302,  ..., -1.8044, -1.8044, -1.8044]]]), 2, 0, 2, 0]
# Dataset contains data with shape: 15 samples.
# Dataset contains targets with length: 15.
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-1.6727, -1.6727, -1.6727,  ..., -0.4397, -0.5253, -0.6281],
#          [-1.6727, -1.6727, -1.6727,  ..., -0.4739, -0.5424, -0.6281],
#          [-1.6727, -1.6727, -1.6727,  ..., -0.4739, -0.5253, -0.5596],
#          ...,
#          [-0.2171, -0.2513, -0.2856,  ...,  0.8961,  0.8789,  0.8789],
#          [-0.2342, -0.2342, -0.2342,  ...,  0.9132,  0.8961,  0.8961],
#          [-0.1999, -0.1999, -0.1999,  ...,  0.9132,  0.8961,  0.8961]],
#
#         [[-1.7031, -1.7031, -1.7031,  ..., -0.8627, -0.9153, -0.9153],
#          [-1.7031, -1.7031, -1.7031,  ..., -0.8978, -0.9328, -0.9153],
#          [-1.7031, -1.7031, -1.7031,  ..., -0.9153, -0.9503, -0.9153],
#          ...,
#          [ 0.0651, -0.0224, -0.0924,  ...,  0.6429,  0.6254,  0.6254],
#          [ 0.0826, -0.0224, -0.0924,  ...,  0.6429,  0.6429,  0.6429],
#          [ 0.1176,  0.0126, -0.0574,  ...,  0.6429,  0.6429,  0.6429]],
#
#         [[-1.6476, -1.6476, -1.6476,  ..., -1.8044, -1.7870, -1.7173],
#          [-1.6476, -1.6476, -1.6476,  ..., -1.8044, -1.7870, -1.7173],
#          [-1.6476, -1.6476, -1.6650,  ..., -1.7347, -1.7696, -1.7696],
#          ...,
#          [ 0.4962,  0.4265,  0.3393,  ..., -1.8044, -1.8044, -1.8044],
#          [ 0.5659,  0.4962,  0.3916,  ..., -1.8044, -1.8044, -1.8044],
#          [ 0.6008,  0.5311,  0.4265,  ..., -1.8044, -1.8044, -1.8044]]]), 1, 0, 1, 0]
# Dataset contains data with shape: 618 samples.
# Dataset contains targets with length: 618.
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-1.5357, -1.6213, -1.6384,  ..., -0.6623, -0.7308, -0.7479],
#          [-1.5357, -1.6042, -1.6213,  ..., -0.6794, -0.7308, -0.7822],
#          [-1.5528, -1.5699, -1.6042,  ..., -0.7137, -0.7479, -0.8164],
#          ...,
#          [-0.7650, -0.7822, -0.7993,  ..., -0.2513, -0.2171, -0.2342],
#          [-0.7479, -0.7650, -0.7822,  ..., -0.2856, -0.2513, -0.2513],
#          [-0.7479, -0.7650, -0.7822,  ..., -0.3198, -0.2684, -0.2513]],
#
#         [[-1.4580, -1.5630, -1.5980,  ..., -0.3901, -0.4951, -0.5476],
#          [-1.4580, -1.5280, -1.5630,  ..., -0.4251, -0.4951, -0.5826],
#          [-1.4580, -1.5105, -1.5455,  ..., -0.4426, -0.4951, -0.5651],
#          ...,
#          [-0.3901, -0.4251, -0.4251,  ...,  0.1176,  0.1527,  0.1352],
#          [-0.3725, -0.4076, -0.4076,  ...,  0.0651,  0.1176,  0.1001],
#          [-0.3901, -0.3901, -0.4251,  ...,  0.0651,  0.1001,  0.0826]],
#
#         [[-1.5953, -1.6127, -1.5430,  ..., -1.5256, -1.4384, -1.3164],
#          [-1.5953, -1.5779, -1.5256,  ..., -1.5430, -1.4384, -1.3513],
#          [-1.6476, -1.5953, -1.5430,  ..., -1.5081, -1.4036, -1.3513],
#          ...,
#          [-1.7696, -1.7173, -1.7522,  ..., -1.6127, -1.5604, -1.5779],
#          [-1.7347, -1.6999, -1.7347,  ..., -1.6999, -1.5953, -1.5604],
#          [-1.6999, -1.7870, -1.6824,  ..., -1.7870, -1.6302, -1.4559]]]), 2, 0, 2, 0]
# Dataset contains data with shape: 75 samples.
# Dataset contains targets with length: 75.
# Dataset is an instance of AvalancheDataset.
# Dataset internal structure: ['__abstractmethods__', '__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__protocol_attrs__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data_attributes', '_datasets', '_flat_data', '_init_collate_fn', '_is_protocol', '_is_runtime_protocol', '_shallow_clone_dataset', '_transform_groups', '_tree_depth', 'collate_fn', 'concat', 'data', 'eval', 'freeze_transforms', 'get_valid_indices', 'remove_current_transform_group', 'replace_current_transform_group', 'root_dir', 'subset', 'targets', 'targets_task_labels', 'task_label', 'train', 'transform', 'update_data_attribute', 'with_transforms']
# Dataset contains 'data', 'targets', and 'task_label' attributes.
# First sample structure: [tensor([[[-1.6384, -1.6555, -1.6898,  ..., -0.4911, -0.5424, -0.4568],
#          [-1.6384, -1.6555, -1.6898,  ..., -0.4739, -0.5253, -0.4568],
#          [-1.6555, -1.6727, -1.7069,  ..., -0.3883, -0.4397, -0.4568],
#          ...,
#          [-1.7925, -1.7925, -1.7754,  ...,  0.0741,  0.2282,  0.2967],
#          [-1.8097, -1.8097, -1.8097,  ...,  0.0227,  0.1939,  0.2796],
#          [-1.8097, -1.7925, -1.8097,  ..., -0.0116,  0.1597,  0.2796]],
#
#         [[-1.4930, -1.4930, -1.5280,  ..., -0.3375, -0.4076, -0.3375],
#          [-1.4930, -1.4930, -1.5280,  ..., -0.3375, -0.4076, -0.3375],
#          [-1.5105, -1.5280, -1.5630,  ..., -0.2850, -0.3725, -0.3725],
#          ...,
#          [-1.6506, -1.6506, -1.6331,  ...,  0.2927,  0.2927,  0.2752],
#          [-1.6681, -1.6681, -1.6681,  ...,  0.2752,  0.2927,  0.2927],
#          [-1.6681, -1.6506, -1.6681,  ...,  0.2402,  0.2752,  0.2927]],
#
#         [[-1.5779, -1.6650, -1.7522,  ..., -1.2119, -1.1596, -1.0027],
#          [-1.5779, -1.6650, -1.7522,  ..., -1.1770, -1.1596, -1.0027],
#          [-1.6302, -1.6302, -1.6824,  ..., -1.0376, -1.0027, -1.0376],
#          ...,
#          [-1.7173, -1.7173, -1.7347,  ..., -1.0027, -0.6018, -0.5844],
#          [-1.7347, -1.7347, -1.7522,  ..., -1.0550, -0.6541, -0.5670],
#          [-1.7347, -1.7173, -1.7522,  ..., -1.0898, -0.6890, -0.5670]]]), 2, 0, 2, 0]
# Dataset contains data with shape: 81 samples.
# Dataset contains targets with length: 81.

# %%
# Function to print all attributes of the dataset
def print_all_attributes(dataset):
    print(f"Attributes of the dataset:")
    for attr in dir(dataset):
        # Skip private attributes (those starting with '_')
        if not attr.startswith('_'):
            print(f"  {attr}")

# Check all datasets in the "train" and "test" streams
dataset_streams = {
    "train": [train_dataset_exp1, train_dataset_exp2, train_dataset_exp3],
    "test": [test_dataset_exp1, test_dataset_exp2, test_dataset_exp3]
}

# Iterate over the streams and check each dataset
for stream_name, datasets in dataset_streams.items():
    print(f"\nChecking {stream_name} datasets:")
    for i, dataset in enumerate(datasets):
        print(f"\n  Checking dataset {stream_name}_{i + 1}:")
        print_all_attributes(dataset)
# Out:
# Checking train datasets:
#
#   Checking dataset train_1:
# Attributes of the dataset:
#   collate_fn
#   concat
#   data
#   eval
#   freeze_transforms
#   get_valid_indices
#   remove_current_transform_group
#   replace_current_transform_group
#   root_dir
#   subset
#   targets
#   targets_task_labels
#   task_label
#   train
#   transform
#   update_data_attribute
#   with_transforms
#
#   Checking dataset train_2:
# Attributes of the dataset:
#   collate_fn
#   concat
#   data
#   eval
#   freeze_transforms
#   get_valid_indices
#   remove_current_transform_group
#   replace_current_transform_group
#   root_dir
#   subset
#   targets
#   targets_task_labels
#   task_label
#   train
#   transform
#   update_data_attribute
#   with_transforms
#
#   Checking dataset train_3:
# Attributes of the dataset:
#   collate_fn
#   concat
#   data
#   eval
#   freeze_transforms
#   get_valid_indices
#   remove_current_transform_group
#   replace_current_transform_group
#   root_dir
#   subset
#   targets
#   targets_task_labels
#   task_label
#   train
#   transform
#   update_data_attribute
#   with_transforms
#
# Checking test datasets:
#
#   Checking dataset test_1:
# Attributes of the dataset:
#   collate_fn
#   concat
#   data
#   eval
#   freeze_transforms
#   get_valid_indices
#   remove_current_transform_group
#   replace_current_transform_group
#   root_dir
#   subset
#   targets
#   targets_task_labels
#   task_label
#   train
#   transform
#   update_data_attribute
#   with_transforms
#
#   Checking dataset test_2:
# Attributes of the dataset:
#   collate_fn
#   concat
#   data
#   eval
#   freeze_transforms
#   get_valid_indices
#   remove_current_transform_group
#   replace_current_transform_group
#   root_dir
#   subset
#   targets
#   targets_task_labels
#   task_label
#   train
#   transform
#   update_data_attribute
#   with_transforms
#
#   Checking dataset test_3:
# Attributes of the dataset:
#   collate_fn
#   concat
#   data
#   eval
#   freeze_transforms
#   get_valid_indices
#   remove_current_transform_group
#   replace_current_transform_group
#   root_dir
#   subset
#   targets
#   targets_task_labels
#   task_label
#   train
#   transform
#   update_data_attribute
#   with_transforms

# %%
# Check if they are instances of AvalancheDataset
print("Is train_dataset_exp1 an AvalancheDataset? ", isinstance(train_dataset_exp1, AvalancheDataset))
print("Is train_dataset_exp2 an AvalancheDataset? ", isinstance(train_dataset_exp2, AvalancheDataset))
print("Is train_dataset_exp3 an AvalancheDataset? ", isinstance(train_dataset_exp3, AvalancheDataset))
# Out:
# Is train_dataset_exp1 an AvalancheDataset?  True
# Is train_dataset_exp2 an AvalancheDataset?  True
# Is train_dataset_exp3 an AvalancheDataset?  True

# %%
def check_dataset(avalanche_dataset):
    try:
        # Access the first sample using __getitem__
        first_sample = avalanche_dataset[0]  # This might be a tuple (image, label, task_label)
        
        # Print the entire first sample to check the structure
        print(f"First sample: {first_sample}")
        
        # Print the type of each element in the sample (image, target, task_label)
        if isinstance(first_sample, tuple):
            print(f"First element type (image): {type(first_sample[0])}")
            print(f"Second element type (target): {type(first_sample[1])}")
            if len(first_sample) >= 3:
                print(f"Third element type (task_label): {type(first_sample[2])}")
            else:
                print("No task label in the sample.")
        else:
            print("The first sample is not a tuple as expected.")

        # Check if the first element (image) is a string (file path) or a tensor
        if isinstance(first_sample[0], str):
            print("The first element is a string, which might be a file path.")
        elif hasattr(first_sample[0], 'shape'):
            print(f"The first element is an image tensor with shape: {first_sample[0].shape}")
        else:
            print("The first element is neither a string nor a tensor.")

        # Check if the dataset has 3 elements (image, target, task_label)
        if len(first_sample) >= 3:
            print(f"Target (label): {first_sample[1]}")
            print(f"Task label: {first_sample[2]}")
        else:
            print("Warning: The dataset does not contain all expected elements (image, target, task_label).")

    except AttributeError as e:
        print(f"Error accessing dataset attributes: {e}")
    except IndexError as e:
        print(f"Error accessing dataset elements: {e}")

# Running the function on the first dataset
check_dataset(train_dataset_exp1)
# Out:
# First sample: [tensor([[[-1.6042, -1.6213, -1.6384,  ..., -0.5424, -0.5938, -0.5767],
#          [-1.6042, -1.6213, -1.6384,  ..., -0.5424, -0.5767, -0.5424],
#          [-1.6042, -1.6384, -1.6727,  ..., -0.4568, -0.4911, -0.4911],
#          ...,
#          [-1.8439, -1.8610, -1.8782,  ...,  0.0227,  0.1083,  0.1426],
#          [-1.8610, -1.8782, -1.8953,  ..., -0.0801,  0.0398,  0.1426],
#          [-1.8610, -1.8953, -1.8953,  ..., -0.1314, -0.0287,  0.0741]],
#
#         [[-1.5105, -1.5105, -1.5105,  ..., -0.3901, -0.4601, -0.4426],
#          [-1.5105, -1.5105, -1.5105,  ..., -0.3725, -0.4601, -0.4426],
#          [-1.4930, -1.5105, -1.5455,  ..., -0.3550, -0.4251, -0.4426],
#          ...,
#          [-1.7206, -1.7206, -1.7206,  ...,  0.2227,  0.2402,  0.2402],
#          [-1.7031, -1.7206, -1.7381,  ...,  0.1877,  0.1877,  0.1877],
#          [-1.6856, -1.7206, -1.7206,  ...,  0.1352,  0.1352,  0.1352]],
#
#         [[-1.2641, -1.3861, -1.4733,  ..., -0.7587, -0.8284, -0.8284],
#          [-1.2641, -1.3861, -1.4733,  ..., -0.7761, -0.7413, -0.5844],
#          [-1.3164, -1.4210, -1.5256,  ..., -0.7064, -0.6193, -0.4798],
#          ...,
#          [-1.3339, -1.3861, -1.4907,  ..., -0.0964, -0.0092,  0.0431],
#          [-1.4559, -1.4733, -1.5081,  ..., -0.2881, -0.1661, -0.0441],
#          [-1.5604, -1.5953, -1.5953,  ..., -0.4450, -0.3230, -0.2010]]]), 1, 0, 1, 0]
# The first sample is not a tuple as expected.
# The first element is an image tensor with shape: torch.Size([3, 224, 224])
# Target (label): 1
# Task label: 0

# %%
sample = train_dataset_exp1[0]
image, label, task_label = sample[:3]
print(f"Image shape: {image.shape}, Label: {label}, Task Label: {task_label}")
# Out:
# Image shape: torch.Size([3, 224, 224]), Label: 1, Task Label: 0

# %% [markdown]
# ## Checking class distribution in each dataset

# %%
import torch
from collections import Counter

def count_classes(dataset):
    # Convert the FlatData into a list of values via list comprehension.
    values = [x for x in dataset.targets]
    # Convert the list of values to a tensor.
    t = torch.tensor(values)
    # Now, convert the tensor to a NumPy array and count the classes.
    return Counter(t.numpy())

print("Class distribution in Train Dataset 1:", count_classes(train_dataset_exp1))
print("Class distribution in Train Dataset 2:", count_classes(train_dataset_exp2))
print("Class distribution in Train Dataset 3:", count_classes(train_dataset_exp3))
print("Class distribution in Test Dataset 1:", count_classes(test_dataset_exp1))
print("Class distribution in Test Dataset 2:", count_classes(test_dataset_exp2))
print("Class distribution in Test Dataset 3:", count_classes(test_dataset_exp3))
# Out:
# Class distribution in Train Dataset 1: Counter({1: 26, 2: 26, 0: 26})
# Class distribution in Train Dataset 2: Counter({1: 31, 0: 31, 2: 31})
# Class distribution in Train Dataset 3: Counter({1: 206, 0: 206, 2: 206})
# Class distribution in Test Dataset 1: Counter({1: 4, 2: 4, 0: 4})
# Class distribution in Test Dataset 2: Counter({2: 5, 0: 5, 1: 5})
# Class distribution in Test Dataset 3: Counter({2: 27, 1: 27, 0: 27})

# %% [markdown]
# ## Checking class distribution in each experience

# %%
from avalanche.benchmarks.utils import DataAttribute
from avalanche.benchmarks import benchmark_from_datasets
# Create the benchmark from your datasets
dataset_streams = {
    "train": [train_dataset_exp1, train_dataset_exp2, train_dataset_exp3],
    "test": [test_dataset_exp1, test_dataset_exp2, test_dataset_exp3]
}
# You might want to ensure the benchmark is created here
benchmark = benchmark_from_datasets(**dataset_streams)

for experience in benchmark.train_stream:
    print(f"Start of experience: {experience.current_experience}")
    
    # Try to get the targets via the dynamic property.
    try:
        targets_data = experience.dataset.targets.data
    except AttributeError:
        # Fallback: access the internal _data_attributes dictionary.
        targets_data = experience.dataset._data_attributes["targets"].data

    # If targets_data doesn't have 'tolist', assume it's already iterable.
    if hasattr(targets_data, "tolist"):
        unique_classes = set(targets_data.tolist())
    else:
        unique_classes = set(targets_data)
        
    print(f"Classes in this experience: {unique_classes}")
# Out:
# Start of experience: 0
# Classes in this experience: {0, 1, 2}
# Start of experience: 1
# Classes in this experience: {0, 1, 2}
# Start of experience: 2
# Classes in this experience: {0, 1, 2}

# %% [markdown]
# # Using Naive Strategy from Avalanche

# %%
import torch
import torch.optim as optim
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader
from avalanche.benchmarks import benchmark_from_datasets
from avalanche.training import Naive
from models.cnn_models import SimpleCNN
from avalanche.logging import TensorboardLogger, TextLogger, InteractiveLogger
from avalanche.training.plugins import EvaluationPlugin
from avalanche.evaluation.metrics import (
    accuracy_metrics,
    loss_metrics,
    timing_metrics,
    cpu_usage_metrics,
    forgetting_metrics,
    StreamConfusionMatrix,
    disk_usage_metrics
)
import csv
import os
from tqdm import tqdm

# -------------------------------------------------
# 1) SETUP AVALANCHE NAIVE STRATEGY
# -------------------------------------------------
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimpleCNN(num_classes=3).to(device)
criterion = CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0)

tb_logger = TensorboardLogger()
text_logger = TextLogger(open('log.txt', 'a'))
interactive_logger = InteractiveLogger()

eval_plugin = EvaluationPlugin(
    accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loss_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    timing_metrics(epoch=True),
    cpu_usage_metrics(experience=True),
    forgetting_metrics(experience=True, stream=True),
    StreamConfusionMatrix(num_classes=3, save_image=False),
    disk_usage_metrics(minibatch=True, epoch=True, experience=True, stream=True),
    loggers=[interactive_logger, text_logger, tb_logger]
)

# Set train_epochs=100 so that each call to cl_strategy.train() runs for 100 epochs internally.
cl_strategy = Naive(
    model=model,
    optimizer=optimizer,
    criterion=criterion,
    train_mb_size=5,
    train_epochs=30,
    eval_mb_size=5,
    # evaluator=eval_plugin,  # Optionally, pass evaluator for built-in metrics logging.
    device=device
)

# -------------------------------------------------
# 2) SETUP BENCHMARK (MULTIPLE EXPERIENCES)
# -------------------------------------------------
dataset_streams = {
    "train": [train_dataset_exp1, train_dataset_exp2, train_dataset_exp3],
    "test": [test_dataset_exp1, test_dataset_exp2, test_dataset_exp3]
}
benchmark = benchmark_from_datasets(**dataset_streams)
validation_datasets = [val_dataset_exp1, val_dataset_exp2, val_dataset_exp3]

# -------------------------------------------------
# 3) TRAINING LOOP ACROSS EXPERIENCES
# -------------------------------------------------
for exp_idx, experience in enumerate(benchmark.train_stream):
    print(f"\n=== Start of Experience {experience.current_experience} ===")
    
    # Create a validation loader for this experience using the corresponding validation dataset.
    val_dataset = validation_datasets[exp_idx]
    val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
    
    # Optionally track losses in a CSV.
    csv_file_path = f"naive_training_validation_experience_{experience.current_experience}.csv"
    if not os.path.exists(csv_file_path):
        with open(csv_file_path, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(["Epoch", "TrainLoss", "ValLoss"])
    
    # Train the model using the Naive strategy for the current experience.
    print(f"Training Experience {experience.current_experience} for 100 epochs...")
    train_res = cl_strategy.train(experience)
    train_loss = train_res.get("Loss_Epoch/train_phase/train_stream", 0.0)
    
    # After training, run validation manually.
    model.eval()
    val_loss_total = 0.0
    val_batches = 0
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for images, labels, *rest in tqdm(val_loader, desc="Validating", leave=False):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss_total += loss.item() * images.size(0)
            val_batches += images.size(0)
            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == labels).sum().item()
            total_val += labels.size(0)
    
    val_epoch_loss = val_loss_total / val_batches if val_batches > 0 else 0.0
    val_epoch_acc = correct_val / total_val if total_val > 0 else 0.0
    
    print(f"Final Training Loss: {train_loss:.4f}, Validation Loss: {val_epoch_loss:.4f}, Validation Acc: {val_epoch_acc:.4f}")
    
    # Log final training and validation loss.
    with open(csv_file_path, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([100, train_loss, val_epoch_loss])
    
    # Evaluate on the entire test stream after each experience.
    print("Testing on the entire test stream...")
    test_res = cl_strategy.eval(benchmark.test_stream)
    print("Test results:", test_res)

print("All Experiences Done.")
# Out:
# === Start of Experience 0 ===
# Training Experience 0 for 100 epochs...
# -- >> Start of training phase << --
# 100%|██████████| 16/16 [00:41<00:00,  2.59s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.1108
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3077
# 100%|██████████| 16/16 [00:16<00:00,  1.03s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.1018
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.2821
# 100%|██████████| 16/16 [00:15<00:00,  1.05it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0971
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3333
# 100%|██████████| 16/16 [00:15<00:00,  1.06it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.1094
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.2692
# 100%|██████████| 16/16 [00:16<00:00,  1.02s/it]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0936
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3846
# 100%|██████████| 16/16 [00:14<00:00,  1.08it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0839
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.4487
# 100%|██████████| 16/16 [00:16<00:00,  1.01s/it]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0759
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3333
# 100%|██████████| 16/16 [00:13<00:00,  1.21it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0576
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5128
# 100%|██████████| 16/16 [00:13<00:00,  1.22it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0503
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.4359
# 100%|██████████| 16/16 [00:13<00:00,  1.17it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0329
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.4744
# 100%|██████████| 16/16 [00:13<00:00,  1.22it/s]
# Epoch 10 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0516
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3974
# 100%|██████████| 16/16 [00:13<00:00,  1.14it/s]
# Epoch 11 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9611
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5897
# 100%|██████████| 16/16 [00:13<00:00,  1.15it/s]
# Epoch 12 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9338
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5769
# 100%|██████████| 16/16 [00:13<00:00,  1.17it/s]
# Epoch 13 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9332
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5769
# 100%|██████████| 16/16 [00:13<00:00,  1.22it/s]
# Epoch 14 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8647
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6026
# 100%|██████████| 16/16 [00:13<00:00,  1.18it/s]
# Epoch 15 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8066
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6667
# 100%|██████████| 16/16 [00:14<00:00,  1.14it/s]
# Epoch 16 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7625
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6154
# 100%|██████████| 16/16 [00:13<00:00,  1.21it/s]
# Epoch 17 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7387
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6282
# 100%|██████████| 16/16 [00:14<00:00,  1.13it/s]
# Epoch 18 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6648
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7179
# 100%|██████████| 16/16 [00:13<00:00,  1.21it/s]
# Epoch 19 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6251
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6923
# 100%|██████████| 16/16 [00:13<00:00,  1.19it/s]
# Epoch 20 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6141
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7436
# 100%|██████████| 16/16 [00:13<00:00,  1.18it/s]
# Epoch 21 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5803
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7692
# 100%|██████████| 16/16 [00:14<00:00,  1.13it/s]
# Epoch 22 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6745
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6410
# 100%|██████████| 16/16 [00:14<00:00,  1.09it/s]
# Epoch 23 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6254
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6410
# 100%|██████████| 16/16 [00:13<00:00,  1.16it/s]
# Epoch 24 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6187
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7692
# 100%|██████████| 16/16 [00:12<00:00,  1.28it/s]
# Epoch 25 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5229
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7949
# 100%|██████████| 16/16 [00:13<00:00,  1.19it/s]
# Epoch 26 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4498
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8462
# 100%|██████████| 16/16 [00:13<00:00,  1.17it/s]
# Epoch 27 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4082
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8077
# 100%|██████████| 16/16 [00:13<00:00,  1.21it/s]
# Epoch 28 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3410
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8974
# 100%|██████████| 16/16 [00:14<00:00,  1.14it/s]
# Epoch 29 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3901
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8077
# -- >> End of training phase << --
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Validating: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# Final Training Loss: 0.3901, Validation Loss: 1.0446, Validation Acc: 0.5556
# Testing on the entire test stream...
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 from test stream --
# 100%|██████████| 3/3 [00:01<00:00,  1.68it/s]
# > Eval on experience 0 from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Exp000 = 1.8245
# 	Top1_Acc_Exp/eval_phase/test_stream/Exp000 = 0.4167
# -- Starting eval on experience 1 from test stream --
# 100%|██████████| 3/3 [00:01<00:00,  1.58it/s]
# > Eval on experience 1 from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Exp001 = 2.0179
# 	Top1_Acc_Exp/eval_phase/test_stream/Exp001 = 0.2667
# -- Starting eval on experience 2 from test stream --
# 100%|██████████| 17/17 [00:08<00:00,  1.91it/s]
# > Eval on experience 2 from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Exp002 = 2.1154
# 	Top1_Acc_Exp/eval_phase/test_stream/Exp002 = 0.3086
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream = 2.0696
# 	Top1_Acc_Stream/eval_phase/test_stream = 0.3148
# Test results: {'Top1_Acc_Epoch/train_phase/train_stream': 0.8076923076923077, 'Loss_Epoch/train_phase/train_stream': 0.390101827107943, 'Top1_Acc_Exp/eval_phase/test_stream/Exp000': 0.4166666666666667, 'Loss_Exp/eval_phase/test_stream/Exp000': 1.8245116968949635, 'Top1_Acc_Exp/eval_phase/test_stream/Exp001': 0.26666666666666666, 'Loss_Exp/eval_phase/test_stream/Exp001': 2.0179073810577393, 'Top1_Acc_Exp/eval_phase/test_stream/Exp002': 0.30864197530864196, 'Loss_Exp/eval_phase/test_stream/Exp002': 2.115415624814269, 'Top1_Acc_Stream/eval_phase/test_stream': 0.3148148148148148, 'Loss_Stream/eval_phase/test_stream': 2.069550154523717}
#
# === Start of Experience 1 ===
# Training Experience 1 for 100 epochs...
# -- >> Start of training phase << --
# 100%|██████████| 19/19 [00:14<00:00,  1.34it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.5492
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3011
# 100%|██████████| 19/19 [00:08<00:00,  2.18it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.1389
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3978
# 100%|██████████| 19/19 [00:08<00:00,  2.16it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.1079
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3441
# 100%|██████████| 19/19 [00:08<00:00,  2.20it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0416
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.4409
# 100%|██████████| 19/19 [00:09<00:00,  2.09it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0133
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5054
# 100%|██████████| 19/19 [00:08<00:00,  2.27it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9593
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5591
# 100%|██████████| 19/19 [00:08<00:00,  2.28it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9174
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5914
# 100%|██████████| 19/19 [00:07<00:00,  2.38it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8624
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6667
# 100%|██████████| 19/19 [00:08<00:00,  2.35it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8460
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6559
# 100%|██████████| 19/19 [00:12<00:00,  1.47it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7687
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6989
# 100%|██████████| 19/19 [00:11<00:00,  1.60it/s]
# Epoch 10 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6400
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7634
# 100%|██████████| 19/19 [00:10<00:00,  1.74it/s]
# Epoch 11 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7003
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6667
# 100%|██████████| 19/19 [00:11<00:00,  1.64it/s]
# Epoch 12 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5287
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8065
# 100%|██████████| 19/19 [00:12<00:00,  1.57it/s]
# Epoch 13 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4639
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8065
# 100%|██████████| 19/19 [00:11<00:00,  1.66it/s]
# Epoch 14 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4705
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8817
# 100%|██████████| 19/19 [00:11<00:00,  1.61it/s]
# Epoch 15 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7494
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6559
# 100%|██████████| 19/19 [00:11<00:00,  1.67it/s]
# Epoch 16 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6788
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7204
# 100%|██████████| 19/19 [00:11<00:00,  1.64it/s]
# Epoch 17 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4473
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7849
# 100%|██████████| 19/19 [00:11<00:00,  1.63it/s]
# Epoch 18 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.2890
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9140
# 100%|██████████| 19/19 [00:11<00:00,  1.70it/s]
# Epoch 19 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.2767
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8817
# 100%|██████████| 19/19 [00:11<00:00,  1.60it/s]
# Epoch 20 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3671
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8602
# 100%|██████████| 19/19 [00:11<00:00,  1.67it/s]
# Epoch 21 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.2885
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9032
# 100%|██████████| 19/19 [00:11<00:00,  1.60it/s]
# Epoch 22 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.1493
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9892
# 100%|██████████| 19/19 [00:14<00:00,  1.34it/s]
# Epoch 23 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.1720
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9677
# 100%|██████████| 19/19 [00:12<00:00,  1.50it/s]
# Epoch 24 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.1084
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9785
# 100%|██████████| 19/19 [00:11<00:00,  1.67it/s]
# Epoch 25 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.0875
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9892
# 100%|██████████| 19/19 [00:12<00:00,  1.52it/s]
# Epoch 26 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.0737
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9785
# 100%|██████████| 19/19 [00:11<00:00,  1.59it/s]
# Epoch 27 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.0632
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9785
# 100%|██████████| 19/19 [00:11<00:00,  1.61it/s]
# Epoch 28 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.0408
# 	Top1_Acc_Epoch/train_phase/train_stream = 1.0000
# 100%|██████████| 19/19 [00:11<00:00,  1.65it/s]
# Epoch 29 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.0205
# 	Top1_Acc_Epoch/train_phase/train_stream = 1.0000
# -- >> End of training phase << --
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Validating: 100%|██████████| 1/1 [00:00<00:00,  1.70it/s]
# Final Training Loss: 0.0205, Validation Loss: 2.7888, Validation Acc: 0.3333
# Testing on the entire test stream...
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 from test stream --
# 100%|██████████| 3/3 [00:00<00:00,  3.08it/s]
# > Eval on experience 0 from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Exp000 = 4.2317
# 	Top1_Acc_Exp/eval_phase/test_stream/Exp000 = 0.0833
# -- Starting eval on experience 1 from test stream --
# 100%|██████████| 3/3 [00:00<00:00,  3.21it/s]
# > Eval on experience 1 from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Exp001 = 1.0298
# 	Top1_Acc_Exp/eval_phase/test_stream/Exp001 = 0.6000
# -- Starting eval on experience 2 from test stream --
# 100%|██████████| 17/17 [00:05<00:00,  3.25it/s]
# > Eval on experience 2 from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Exp002 = 3.5687
# 	Top1_Acc_Exp/eval_phase/test_stream/Exp002 = 0.2469
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream = 3.2898
# 	Top1_Acc_Stream/eval_phase/test_stream = 0.2778
# Test results: {'Top1_Acc_Epoch/train_phase/train_stream': 1.0, 'Loss_Epoch/train_phase/train_stream': 0.02053468231792732, 'Top1_Acc_Exp/eval_phase/test_stream/Exp000': 0.08333333333333333, 'Loss_Exp/eval_phase/test_stream/Exp000': 4.231715599695842, 'Top1_Acc_Exp/eval_phase/test_stream/Exp001': 0.6, 'Loss_Exp/eval_phase/test_stream/Exp001': 1.0297902524471283, 'Top1_Acc_Exp/eval_phase/test_stream/Exp002': 0.24691358024691357, 'Loss_Exp/eval_phase/test_stream/Exp002': 3.5687417380603743, 'Top1_Acc_Stream/eval_phase/test_stream': 0.2777777777777778, 'Loss_Stream/eval_phase/test_stream': 3.2897733496846975}
#
# === Start of Experience 2 ===
# Training Experience 2 for 100 epochs...
# -- >> Start of training phase << --
# 100%|██████████| 124/124 [01:16<00:00,  1.61it/s]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.3635
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3641
# 100%|██████████| 124/124 [00:59<00:00,  2.10it/s]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0603
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.4482
# 100%|██████████| 124/124 [00:59<00:00,  2.08it/s]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9991
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.4903
# 100%|██████████| 124/124 [01:27<00:00,  1.42it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9531
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5178
# 100%|██████████| 124/124 [01:06<00:00,  1.86it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9454
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5453
#  37%|███▋      | 46/124 [00:28<00:38,  2.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 87
#      85 # Train the model using the Naive strategy for the current experience.
#      86 print(f"Training Experience {experience.current_experience} for 100 epochs...")
# ---> 87 train_res = cl_strategy.train(experience)
#      88 train_loss = train_res.get("Loss_Epoch/train_phase/train_stream", 0.0)
#      90 # After training, run validation manually.
#
# File ~\avalanche\venv\Lib\site-packages\avalanche\training\templates\base_sgd.py:211, in BaseSGDTemplate.train(self, experiences, eval_streams, **kwargs)
#     203 def train(
#     204     self,
#     205     experiences: Union[TDatasetExperience, Iterable[TDatasetExperience]],
#    (...)
#     209     **kwargs
#     210 ):
# --> 211     super().train(experiences, eval_streams, **kwargs)
#     212     return self.evaluator.get_last_metrics()
#
# File ~\avalanche\venv\Lib\site-packages\avalanche\training\templates\base.py:163, in BaseTemplate.train(self, experiences, eval_streams, **kwargs)
#     161 for self.experience in experiences_list:
#     162     self._before_training_exp(**kwargs)
# --> 163     self._train_exp(self.experience, eval_streams, **kwargs)
#     164     self._after_training_exp(**kwargs)
#     165 self._after_training(**kwargs)
#
# File ~\avalanche\venv\Lib\site-packages\avalanche\training\templates\base_sgd.py:337, in BaseSGDTemplate._train_exp(self, experience, eval_streams, **kwargs)
#     334     self._stop_training = False
#     335     break
# --> 337 self.training_epoch(**kwargs)
#     338 self._after_training_epoch(**kwargs)
#
# File ~\avalanche\venv\Lib\site-packages\avalanche\training\templates\update_type\sgd_update.py:38, in SGDUpdate.training_epoch(self, **kwargs)
#      35 self.loss += self.criterion()
#      37 self._before_backward(**kwargs)
# ---> 38 self.backward()
#      39 self._after_backward(**kwargs)
#      41 # Optimization step
#
# File ~\avalanche\venv\Lib\site-packages\avalanche\training\templates\base_sgd.py:259, in BaseSGDTemplate.backward(self)
#     257 def backward(self):
#     258     """Run the backward pass."""
# --> 259     self.loss.backward(retain_graph=self.retain_graph)
#
# File ~\avalanche\venv\Lib\site-packages\torch\_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~\avalanche\venv\Lib\site-packages\torch\autograd\__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~\avalanche\venv\Lib\site-packages\torch\autograd\graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Overfitting Test

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader
from avalanche.training import Naive
from avalanche.benchmarks import benchmark_from_datasets
from models.cnn_models import SimpleCNN

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize the model and move it to the device
model = SimpleCNN(num_classes=3).to(device)

# Define your loss function and optimizer with a high learning rate for overfitting test
criterion = CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=0)  # High LR, no weight decay

# Disable dropout in the model to aid overfitting
def disable_dropout(model):
    for m in model.modules():
        if isinstance(m, nn.Dropout):
            m.p = 0.0

disable_dropout(model)

# Create subsets of your AvalancheDataset (assuming train_dataset_exp1 exists)
# Here, we take the first 30 samples for training and use the same set for evaluation.
small_train_dataset = train_dataset_exp1.subset(list(range(30)))
small_test_dataset = train_dataset_exp1.subset(list(range(30)))

# Create a benchmark from these subsets
small_benchmark = benchmark_from_datasets(train=[small_train_dataset],
                                          test=[small_test_dataset])

# Create an Naive strategy instance.
cl_strategy = Naive(
    model=model,
    optimizer=optimizer,
    criterion=criterion,
    train_mb_size=5,
    train_epochs=100,
    eval_mb_size=5,
    ewc_lambda=0.0,
    device=device
)

# Run training on the small benchmark
for experience in small_benchmark.train_stream:
    print(f"=== Overfitting Test on Small Subset, Experience {experience.current_experience} ===")
    cl_strategy.train(experience)
    
    # Evaluate on the training subset to check if the model overfits
    train_eval_res = cl_strategy.eval(small_benchmark.test_stream)
    print("Evaluation on training subset:", train_eval_res)
    
    # Optionally, print predictions on a few samples to verify correctness
    for sample in small_benchmark.test_stream[0].dataset:
        image, label, *rest = sample
        image = image.to(device).unsqueeze(0)  # Add batch dimension
        output = model(image)
        predicted_class = output.argmax(dim=1).item()
        print(f"True label: {label}, Predicted: {predicted_class}")
        break  # Print only one sample per experience
# Out:
# === Overfitting Test on Small Subset, Experience 0 ===
# -- >> Start of training phase << --
# 100%|██████████| 6/6 [00:12<00:00,  2.05s/it]
# Epoch 0 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.1001
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.2667
# 100%|██████████| 6/6 [00:10<00:00,  1.77s/it]
# Epoch 1 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0987
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3333
# 100%|██████████| 6/6 [00:06<00:00,  1.07s/it]
# Epoch 2 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0976
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3333
# 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Epoch 3 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0968
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3333
# 100%|██████████| 6/6 [00:02<00:00,  2.26it/s]
# Epoch 4 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0964
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.3333
# 100%|██████████| 6/6 [00:02<00:00,  2.36it/s]
# Epoch 5 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0956
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5000
# 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Epoch 6 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0950
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5000
# 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Epoch 7 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0943
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5333
# 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Epoch 8 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0941
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5667
# 100%|██████████| 6/6 [00:02<00:00,  2.14it/s]
# Epoch 9 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0929
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5667
# 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Epoch 10 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0922
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.5667
# 100%|██████████| 6/6 [00:02<00:00,  2.33it/s]
# Epoch 11 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0916
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6000
# 100%|██████████| 6/6 [00:02<00:00,  2.38it/s]
# Epoch 12 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0907
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6000
# 100%|██████████| 6/6 [00:02<00:00,  2.17it/s]
# Epoch 13 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0902
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6333
# 100%|██████████| 6/6 [00:02<00:00,  2.37it/s]
# Epoch 14 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0890
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6000
# 100%|██████████| 6/6 [00:02<00:00,  2.33it/s]
# Epoch 15 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0886
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6000
# 100%|██████████| 6/6 [00:02<00:00,  2.37it/s]
# Epoch 16 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0872
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6000
# 100%|██████████| 6/6 [00:02<00:00,  2.34it/s]
# Epoch 17 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0861
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6333
# 100%|██████████| 6/6 [00:02<00:00,  2.37it/s]
# Epoch 18 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0849
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6667
# 100%|██████████| 6/6 [00:02<00:00,  2.33it/s]
# Epoch 19 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0836
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.6667
# 100%|██████████| 6/6 [00:02<00:00,  2.33it/s]
# Epoch 20 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0825
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7000
# 100%|██████████| 6/6 [00:02<00:00,  2.35it/s]
# Epoch 21 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0806
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7333
# 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Epoch 22 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0787
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7333
# 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# Epoch 23 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0781
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Epoch 24 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0762
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.00it/s]
# Epoch 25 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0729
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.35it/s]
# Epoch 26 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0710
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.10it/s]
# Epoch 27 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0695
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.33it/s]
# Epoch 28 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0660
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7333
# 100%|██████████| 6/6 [00:02<00:00,  2.35it/s]
# Epoch 29 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0627
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Epoch 30 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0601
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.37it/s]
# Epoch 31 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0559
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.31it/s]
# Epoch 32 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0520
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.23it/s]
# Epoch 33 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0474
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.13it/s]
# Epoch 34 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0448
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Epoch 35 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0378
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Epoch 36 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0354
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.17it/s]
# Epoch 37 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0286
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Epoch 38 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0210
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# Epoch 39 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0166
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Epoch 40 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0078
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.27it/s]
# Epoch 41 ended.
# 	Loss_Epoch/train_phase/train_stream = 1.0025
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.37it/s]
# Epoch 42 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9903
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.36it/s]
# Epoch 43 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9858
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.29it/s]
# Epoch 44 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9766
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Epoch 45 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9619
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.34it/s]
# Epoch 46 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9520
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Epoch 47 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9484
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.31it/s]
# Epoch 48 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9310
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Epoch 49 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9257
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Epoch 50 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.9064
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:03<00:00,  1.81it/s]
# Epoch 51 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8948
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Epoch 52 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8730
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.19it/s]
# Epoch 53 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8677
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.23it/s]
# Epoch 54 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8514
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.26it/s]
# Epoch 55 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8275
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Epoch 56 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8081
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.18it/s]
# Epoch 57 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.8021
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.12it/s]
# Epoch 58 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7786
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Epoch 59 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7569
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.27it/s]
# Epoch 60 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7370
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.33it/s]
# Epoch 61 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7332
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.7667
# 100%|██████████| 6/6 [00:02<00:00,  2.23it/s]
# Epoch 62 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.7041
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Epoch 63 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6880
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Epoch 64 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6638
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.34it/s]
# Epoch 65 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6514
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.17it/s]
# Epoch 66 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6299
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Epoch 67 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6174
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Epoch 68 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.6029
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8000
# 100%|██████████| 6/6 [00:02<00:00,  2.31it/s]
# Epoch 69 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5843
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:03<00:00,  1.88it/s]
# Epoch 70 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5691
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.17it/s]
# Epoch 71 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5530
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Epoch 72 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5541
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.09it/s]
# Epoch 73 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5175
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.27it/s]
# Epoch 74 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.5156
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Epoch 75 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4885
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Epoch 76 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4890
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Epoch 77 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4626
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.32it/s]
# Epoch 78 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4520
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.26it/s]
# Epoch 79 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4455
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.26it/s]
# Epoch 80 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4442
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.22it/s]
# Epoch 81 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4248
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8333
# 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Epoch 82 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.4302
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9000
# 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Epoch 83 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3931
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9000
# 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Epoch 84 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3940
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.27it/s]
# Epoch 85 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3782
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9000
# 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
# Epoch 86 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3790
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:02<00:00,  2.29it/s]
# Epoch 87 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3602
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.8667
# 100%|██████████| 6/6 [00:03<00:00,  1.96it/s]
# Epoch 88 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3462
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9333
# 100%|██████████| 6/6 [00:02<00:00,  2.28it/s]
# Epoch 89 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3416
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9000
# 100%|██████████| 6/6 [00:02<00:00,  2.23it/s]
# Epoch 90 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3392
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9000
# 100%|██████████| 6/6 [00:02<00:00,  2.18it/s]
# Epoch 91 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3162
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9333
# 100%|██████████| 6/6 [00:02<00:00,  2.04it/s]
# Epoch 92 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3149
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9000
# 100%|██████████| 6/6 [00:02<00:00,  2.24it/s]
# Epoch 93 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3079
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9333
# 100%|██████████| 6/6 [00:02<00:00,  2.09it/s]
# Epoch 94 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.3069
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9000
# 100%|██████████| 6/6 [00:02<00:00,  2.15it/s]
# Epoch 95 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.2895
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9333
# 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Epoch 96 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.2890
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9667
# 100%|██████████| 6/6 [00:02<00:00,  2.25it/s]
# Epoch 97 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.2926
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9333
# 100%|██████████| 6/6 [00:02<00:00,  2.35it/s]
# Epoch 98 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.2652
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9333
# 100%|██████████| 6/6 [00:02<00:00,  2.30it/s]
# Epoch 99 ended.
# 	Loss_Epoch/train_phase/train_stream = 0.2680
# 	Top1_Acc_Epoch/train_phase/train_stream = 0.9667
# -- >> End of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 from test stream --
# 100%|██████████| 6/6 [00:01<00:00,  3.84it/s]
# > Eval on experience 0 from test stream ended.
# 	Loss_Exp/eval_phase/test_stream/Exp000 = 0.2538
# 	Top1_Acc_Exp/eval_phase/test_stream/Exp000 = 0.9667
# -- >> End of eval phase << --
# 	Loss_Stream/eval_phase/test_stream = 0.2538
# 	Top1_Acc_Stream/eval_phase/test_stream = 0.9667
# Evaluation on training subset: {'Top1_Acc_Epoch/train_phase/train_stream': 0.9666666666666667, 'Loss_Epoch/train_phase/train_stream': 0.2679777095715205, 'Top1_Acc_Exp/eval_phase/test_stream/Exp000': 0.9666666666666667, 'Loss_Exp/eval_phase/test_stream/Exp000': 0.25382602338989574, 'Top1_Acc_Stream/eval_phase/test_stream': 0.9666666666666667, 'Loss_Stream/eval_phase/test_stream': 0.25382602338989574}
# True label: 2, Predicted: 2
